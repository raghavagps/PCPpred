# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.cm as cm
import numpy as np

dataframes = ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)',
              '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']

ablation_results = {}

for ablation_idx in range(len(dataframes)):
    print(f"========== Ablation: Excluding feature at index {ablation_idx} ==========")
    excluded_dataframe = dataframes[ablation_idx]
    print('Excluded dataframe:', excluded_dataframe)

    ablated_dataframes = [pair for i, pair in enumerate(dataframes) if i != ablation_idx]
    print('Ablated index', ablation_idx, '----->', 'Ablated_dataframes', ablated_dataframes)
# Out:
# ========== Ablation: Excluding feature at index 0 ==========
# Excluded dataframe: (df_desc_train, df_desc_test)
# Ablated index 0 -----> Ablated_dataframes ['(df_fp_train, df_fp_test)', '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 1 ==========
# Excluded dataframe: (df_fp_train, df_fp_test)
# Ablated index 1 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 2 ==========
# Excluded dataframe: (df_emb_train, df_emb_test)
# Ablated index 2 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 3 ==========
# Excluded dataframe: (df_atomic_train, df_atomic_test)
# Ablated index 3 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)', '(df_emb_train, df_emb_test)']

# %%
ablation_result_dir = '/home/users/akshay/PCPpred/RRCK/results/Ablation/'

ablation_results = {}
for filename in os.listdir(ablation_result_dir):
    if filename.endswith('.csv'):
        ablation_label = filename.replace('.csv', '').replace("Ablation_", "")
        print(ablation_label)
        file_path = os.path.join(ablation_result_dir, filename)
    
        ablation_results[ablation_label] = pd.read_csv(file_path, index_col=0)


ablation_results
# Out:
# Descriptor
# Atomic
# Embeddings
# Fingerprints
# {'Descriptor':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.197021               0.359529
#  DecisionTreeRegressor                   0.277550               0.405393
#  RandomForestRegressor                   0.174022               0.331177
#  GradientBoostingRegressor               0.195507               0.345701
#  AdaBoostRegressor                       0.189692               0.346669
#  XGBRegressor                            0.218648               0.367890
#  ExtraTreesRegressor                     0.182434               0.329761
#  LinearRegression                        0.190728               0.333497
#  KNeighborsRegressor                     0.184178               0.342593
#  SVR                                     0.182775               0.341978
#  MLPRegressor                            0.536169               0.632428
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.443871              0.496611
#  DecisionTreeRegressor                    0.526830              0.290861
#  RandomForestRegressor                    0.417159              0.555375
#  GradientBoostingRegressor                0.442162              0.500479
#  AdaBoostRegressor                        0.435536              0.515339
#  XGBRegressor                             0.467598              0.441356
#  ExtraTreesRegressor                      0.427122              0.533883
#  LinearRegression                         0.436725              0.512690
#  KNeighborsRegressor                      0.429160              0.529426
#  SVR                                      0.427522              0.533011
#  MLPRegressor                             0.732236             -0.369911
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.708960               0.715423
#  DecisionTreeRegressor                   0.640421               0.646671
#  RandomForestRegressor                   0.745852               0.749438
#  GradientBoostingRegressor               0.715603               0.729033
#  AdaBoostRegressor                       0.719640               0.725556
#  XGBRegressor                            0.687009               0.687144
#  ExtraTreesRegressor                     0.732209               0.733660
#  LinearRegression                        0.730168               0.716161
#  KNeighborsRegressor                     0.728675               0.711884
#  SVR                                     0.731412               0.729433
#  MLPRegressor                            0.659451               0.654457
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.204444  0.309757   0.452154  0.557374  0.747261
#  DecisionTreeRegressor      0.219153  0.312400   0.468138  0.525527  0.728708
#  RandomForestRegressor      0.208343  0.321747   0.456446  0.548932  0.742515
#  GradientBoostingRegressor  0.203600  0.313366   0.451220  0.559201  0.749707
#  AdaBoostRegressor          0.224460  0.328565   0.473772  0.514038  0.721301
#  XGBRegressor               0.214407  0.332547   0.463041  0.535803  0.735699
#  ExtraTreesRegressor        0.189268  0.314460   0.435049  0.590229  0.769878
#  LinearRegression           0.210186  0.339614   0.458460  0.544942  0.739321
#  KNeighborsRegressor        0.202461  0.307137   0.449957  0.561666  0.749872
#  SVR                        0.193496  0.312720   0.439881  0.581077  0.763323
#  MLPRegressor               0.600266  0.712802   0.774768 -0.299594  0.699149
#
#                             Test SCC
#  LGBMRegressor              0.700707
#  DecisionTreeRegressor      0.737742
#  RandomForestRegressor      0.729285
#  GradientBoostingRegressor  0.722701
#  AdaBoostRegressor          0.721860
#  XGBRegressor               0.704910
#  ExtraTreesRegressor        0.749037
#  LinearRegression           0.708412
#  KNeighborsRegressor        0.710513
#  SVR                        0.736990
#  MLPRegressor               0.648596  ,
#  'Atomic':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.144988               0.303464
#  DecisionTreeRegressor                   0.277616               0.397446
#  RandomForestRegressor                   0.139228               0.300176
#  GradientBoostingRegressor               0.152454               0.312947
#  AdaBoostRegressor                       0.155883               0.313521
#  XGBRegressor                            0.167545               0.312322
#  ExtraTreesRegressor                     0.140872               0.301049
#  LinearRegression                        0.171093               0.326918
#  KNeighborsRegressor                     0.167853               0.322725
#  SVR                                     0.146226               0.302014
#  MLPRegressor                            0.482449               0.603053
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.380772              0.629557
#  DecisionTreeRegressor                    0.526893              0.290692
#  RandomForestRegressor                    0.373133              0.644272
#  GradientBoostingRegressor                0.390454              0.610480
#  AdaBoostRegressor                        0.394821              0.601718
#  XGBRegressor                             0.409322              0.571924
#  ExtraTreesRegressor                      0.375329              0.640073
#  LinearRegression                         0.413634              0.562857
#  KNeighborsRegressor                      0.409698              0.571137
#  SVR                                      0.382395              0.626393
#  MLPRegressor                             0.694585             -0.232655
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.794852               0.781978
#  DecisionTreeRegressor                   0.639043               0.620156
#  RandomForestRegressor                   0.802909               0.787006
#  GradientBoostingRegressor               0.786688               0.779245
#  AdaBoostRegressor                       0.777389               0.758155
#  XGBRegressor                            0.764343               0.750083
#  ExtraTreesRegressor                     0.800295               0.784104
#  LinearRegression                        0.765331               0.733216
#  KNeighborsRegressor                     0.757806               0.758163
#  SVR                                     0.791746               0.786285
#  MLPRegressor                            0.739243               0.737916
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.244533  0.361262   0.494503  0.470579  0.689781
#  DecisionTreeRegressor      0.198031  0.315714   0.445007  0.571256  0.759345
#  RandomForestRegressor      0.218663  0.324637   0.467615  0.526587  0.726057
#  GradientBoostingRegressor  0.218770  0.330436   0.467728  0.526358  0.726681
#  AdaBoostRegressor          0.201483  0.314040   0.448868  0.563784  0.751794
#  XGBRegressor               0.214609  0.337148   0.463259  0.535365  0.733653
#  ExtraTreesRegressor        0.212531  0.313193   0.461011  0.539864  0.735019
#  LinearRegression           0.238410  0.355349   0.488272  0.483836  0.697317
#  KNeighborsRegressor        0.245387  0.348937   0.495366  0.468729  0.688601
#  SVR                        0.247179  0.344512   0.497171  0.464851  0.691615
#  MLPRegressor               0.701036  0.758046   0.837279 -0.517762  0.610303
#
#                             Test SCC
#  LGBMRegressor              0.626882
#  DecisionTreeRegressor      0.693003
#  RandomForestRegressor      0.644393
#  GradientBoostingRegressor  0.637389
#  AdaBoostRegressor          0.669608
#  XGBRegressor               0.682496
#  ExtraTreesRegressor        0.652378
#  LinearRegression           0.632346
#  KNeighborsRegressor        0.612454
#  SVR                        0.629544
#  MLPRegressor               0.578973  ,
#  'Embeddings':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.170406               0.336995
#  DecisionTreeRegressor                   0.238972               0.379232
#  RandomForestRegressor                   0.161184               0.323493
#  GradientBoostingRegressor               0.180552               0.339858
#  AdaBoostRegressor                       0.167832               0.329176
#  XGBRegressor                            0.206516               0.349788
#  ExtraTreesRegressor                     0.163785               0.327675
#  LinearRegression                        0.215530               0.370999
#  KNeighborsRegressor                     0.177825               0.331929
#  SVR                                     0.186623               0.347102
#  MLPRegressor                            0.519958               0.618302
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.412803              0.564612
#  DecisionTreeRegressor                    0.488847              0.389428
#  RandomForestRegressor                    0.401477              0.588176
#  GradientBoostingRegressor                0.424914              0.538691
#  AdaBoostRegressor                        0.409673              0.571191
#  XGBRegressor                             0.454441              0.472351
#  ExtraTreesRegressor                      0.404704              0.581529
#  LinearRegression                         0.464252              0.449321
#  KNeighborsRegressor                      0.421692              0.545659
#  SVR                                      0.431999              0.523179
#  MLPRegressor                             0.721081             -0.328490
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.757037               0.743458
#  DecisionTreeRegressor                   0.698068               0.683403
#  RandomForestRegressor                   0.768768               0.744943
#  GradientBoostingRegressor               0.748058               0.722293
#  AdaBoostRegressor                       0.758646               0.750486
#  XGBRegressor                            0.707723               0.689925
#  ExtraTreesRegressor                     0.765208               0.742462
#  LinearRegression                        0.706833               0.692302
#  KNeighborsRegressor                     0.739904               0.727627
#  SVR                                     0.726337               0.713287
#  MLPRegressor                            0.707276               0.699418
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.248183  0.363983   0.498179  0.462678  0.681579
#  DecisionTreeRegressor      0.271932  0.394314   0.521471  0.411260  0.650657
#  RandomForestRegressor      0.228765  0.344990   0.478294  0.504716  0.710435
#  GradientBoostingRegressor  0.240182  0.353769   0.490084  0.479999  0.693640
#  AdaBoostRegressor          0.215954  0.344488   0.464709  0.532453  0.731031
#  XGBRegressor               0.231137  0.349493   0.480767  0.499582  0.707025
#  ExtraTreesRegressor        0.212701  0.325147   0.461195  0.539496  0.736287
#  LinearRegression           0.259240  0.362942   0.509156  0.438737  0.662818
#  KNeighborsRegressor        0.258263  0.346297   0.508196  0.440854  0.667829
#  SVR                        0.238770  0.319843   0.488641  0.483057  0.700128
#  MLPRegressor               0.676057  0.735297   0.822227 -0.463683  0.591883
#
#                             Test SCC
#  LGBMRegressor              0.602367
#  DecisionTreeRegressor      0.531624
#  RandomForestRegressor      0.614975
#  GradientBoostingRegressor  0.567346
#  AdaBoostRegressor          0.659802
#  XGBRegressor               0.594383
#  ExtraTreesRegressor        0.628423
#  LinearRegression           0.625482
#  KNeighborsRegressor        0.586398
#  SVR                        0.626182
#  MLPRegressor               0.552077  ,
#  'Fingerprints':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.147760               0.304641
#  DecisionTreeRegressor                   0.289676               0.423661
#  RandomForestRegressor                   0.141792               0.295522
#  GradientBoostingRegressor               0.155116               0.311020
#  AdaBoostRegressor                       0.152585               0.311924
#  XGBRegressor                            0.182745               0.337175
#  ExtraTreesRegressor                     0.138237               0.297908
#  LinearRegression                        0.172601               0.331827
#  KNeighborsRegressor                     0.144874               0.302436
#  SVR                                     0.147022               0.303863
#  MLPRegressor                            0.565028               0.654491
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.384395              0.622474
#  DecisionTreeRegressor                    0.538216              0.259879
#  RandomForestRegressor                    0.376553              0.637722
#  GradientBoostingRegressor                0.393848              0.603679
#  AdaBoostRegressor                        0.390621              0.610147
#  XGBRegressor                             0.427487              0.533087
#  ExtraTreesRegressor                      0.371803              0.646804
#  LinearRegression                         0.415453              0.559005
#  KNeighborsRegressor                      0.380623              0.629848
#  SVR                                      0.383434              0.624359
#  MLPRegressor                             0.751684             -0.443646
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.789822               0.783412
#  DecisionTreeRegressor                   0.627204               0.584480
#  RandomForestRegressor                   0.799374               0.788119
#  GradientBoostingRegressor               0.782717               0.771215
#  AdaBoostRegressor                       0.783511               0.764530
#  XGBRegressor                            0.746718               0.733918
#  ExtraTreesRegressor                     0.804451               0.795014
#  LinearRegression                        0.755506               0.745889
#  KNeighborsRegressor                     0.794347               0.779814
#  SVR                                     0.790909               0.790022
#  MLPRegressor                            0.768759               0.763189
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.246777  0.352395   0.496767  0.465720  0.687319
#  DecisionTreeRegressor      0.184418  0.311757   0.429439  0.600729  0.775777
#  RandomForestRegressor      0.214341  0.319853   0.462970  0.535945  0.732457
#  GradientBoostingRegressor  0.217020  0.317298   0.465854  0.530145  0.730716
#  AdaBoostRegressor          0.204742  0.318904   0.452485  0.556727  0.746545
#  XGBRegressor               0.216763  0.322244   0.465578  0.530702  0.734612
#  ExtraTreesRegressor        0.212917  0.314888   0.461429  0.539029  0.734440
#  LinearRegression           0.223108  0.337092   0.472344  0.516964  0.719215
#  KNeighborsRegressor        0.253985  0.354634   0.503969  0.450115  0.674979
#  SVR                        0.253808  0.341079   0.503794  0.450498  0.680447
#  MLPRegressor               0.771088  0.821578   0.878116 -0.669427  0.630529
#
#                             Test SCC
#  LGBMRegressor              0.634447
#  DecisionTreeRegressor      0.717568
#  RandomForestRegressor      0.657001
#  GradientBoostingRegressor  0.636128
#  AdaBoostRegressor          0.693983
#  XGBRegressor               0.680675
#  ExtraTreesRegressor        0.683197
#  LinearRegression           0.639210
#  KNeighborsRegressor        0.605309
#  SVR                        0.620298
#  MLPRegressor               0.587378  }

# %%
ablation_results.items()
# Out:
# dict_items([('Descriptor',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.197021               0.359529
# DecisionTreeRegressor                   0.277550               0.405393
# RandomForestRegressor                   0.174022               0.331177
# GradientBoostingRegressor               0.195507               0.345701
# AdaBoostRegressor                       0.189692               0.346669
# XGBRegressor                            0.218648               0.367890
# ExtraTreesRegressor                     0.182434               0.329761
# LinearRegression                        0.190728               0.333497
# KNeighborsRegressor                     0.184178               0.342593
# SVR                                     0.182775               0.341978
# MLPRegressor                            0.536169               0.632428
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.443871              0.496611
# DecisionTreeRegressor                    0.526830              0.290861
# RandomForestRegressor                    0.417159              0.555375
# GradientBoostingRegressor                0.442162              0.500479
# AdaBoostRegressor                        0.435536              0.515339
# XGBRegressor                             0.467598              0.441356
# ExtraTreesRegressor                      0.427122              0.533883
# LinearRegression                         0.436725              0.512690
# KNeighborsRegressor                      0.429160              0.529426
# SVR                                      0.427522              0.533011
# MLPRegressor                             0.732236             -0.369911
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.708960               0.715423
# DecisionTreeRegressor                   0.640421               0.646671
# RandomForestRegressor                   0.745852               0.749438
# GradientBoostingRegressor               0.715603               0.729033
# AdaBoostRegressor                       0.719640               0.725556
# XGBRegressor                            0.687009               0.687144
# ExtraTreesRegressor                     0.732209               0.733660
# LinearRegression                        0.730168               0.716161
# KNeighborsRegressor                     0.728675               0.711884
# SVR                                     0.731412               0.729433
# MLPRegressor                            0.659451               0.654457
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.204444  0.309757   0.452154  0.557374  0.747261
# DecisionTreeRegressor      0.219153  0.312400   0.468138  0.525527  0.728708
# RandomForestRegressor      0.208343  0.321747   0.456446  0.548932  0.742515
# GradientBoostingRegressor  0.203600  0.313366   0.451220  0.559201  0.749707
# AdaBoostRegressor          0.224460  0.328565   0.473772  0.514038  0.721301
# XGBRegressor               0.214407  0.332547   0.463041  0.535803  0.735699
# ExtraTreesRegressor        0.189268  0.314460   0.435049  0.590229  0.769878
# LinearRegression           0.210186  0.339614   0.458460  0.544942  0.739321
# KNeighborsRegressor        0.202461  0.307137   0.449957  0.561666  0.749872
# SVR                        0.193496  0.312720   0.439881  0.581077  0.763323
# MLPRegressor               0.600266  0.712802   0.774768 -0.299594  0.699149
#
#                            Test SCC
# LGBMRegressor              0.700707
# DecisionTreeRegressor      0.737742
# RandomForestRegressor      0.729285
# GradientBoostingRegressor  0.722701
# AdaBoostRegressor          0.721860
# XGBRegressor               0.704910
# ExtraTreesRegressor        0.749037
# LinearRegression           0.708412
# KNeighborsRegressor        0.710513
# SVR                        0.736990
# MLPRegressor               0.648596  ), ('Atomic',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.144988               0.303464
# DecisionTreeRegressor                   0.277616               0.397446
# RandomForestRegressor                   0.139228               0.300176
# GradientBoostingRegressor               0.152454               0.312947
# AdaBoostRegressor                       0.155883               0.313521
# XGBRegressor                            0.167545               0.312322
# ExtraTreesRegressor                     0.140872               0.301049
# LinearRegression                        0.171093               0.326918
# KNeighborsRegressor                     0.167853               0.322725
# SVR                                     0.146226               0.302014
# MLPRegressor                            0.482449               0.603053
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.380772              0.629557
# DecisionTreeRegressor                    0.526893              0.290692
# RandomForestRegressor                    0.373133              0.644272
# GradientBoostingRegressor                0.390454              0.610480
# AdaBoostRegressor                        0.394821              0.601718
# XGBRegressor                             0.409322              0.571924
# ExtraTreesRegressor                      0.375329              0.640073
# LinearRegression                         0.413634              0.562857
# KNeighborsRegressor                      0.409698              0.571137
# SVR                                      0.382395              0.626393
# MLPRegressor                             0.694585             -0.232655
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.794852               0.781978
# DecisionTreeRegressor                   0.639043               0.620156
# RandomForestRegressor                   0.802909               0.787006
# GradientBoostingRegressor               0.786688               0.779245
# AdaBoostRegressor                       0.777389               0.758155
# XGBRegressor                            0.764343               0.750083
# ExtraTreesRegressor                     0.800295               0.784104
# LinearRegression                        0.765331               0.733216
# KNeighborsRegressor                     0.757806               0.758163
# SVR                                     0.791746               0.786285
# MLPRegressor                            0.739243               0.737916
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.244533  0.361262   0.494503  0.470579  0.689781
# DecisionTreeRegressor      0.198031  0.315714   0.445007  0.571256  0.759345
# RandomForestRegressor      0.218663  0.324637   0.467615  0.526587  0.726057
# GradientBoostingRegressor  0.218770  0.330436   0.467728  0.526358  0.726681
# AdaBoostRegressor          0.201483  0.314040   0.448868  0.563784  0.751794
# XGBRegressor               0.214609  0.337148   0.463259  0.535365  0.733653
# ExtraTreesRegressor        0.212531  0.313193   0.461011  0.539864  0.735019
# LinearRegression           0.238410  0.355349   0.488272  0.483836  0.697317
# KNeighborsRegressor        0.245387  0.348937   0.495366  0.468729  0.688601
# SVR                        0.247179  0.344512   0.497171  0.464851  0.691615
# MLPRegressor               0.701036  0.758046   0.837279 -0.517762  0.610303
#
#                            Test SCC
# LGBMRegressor              0.626882
# DecisionTreeRegressor      0.693003
# RandomForestRegressor      0.644393
# GradientBoostingRegressor  0.637389
# AdaBoostRegressor          0.669608
# XGBRegressor               0.682496
# ExtraTreesRegressor        0.652378
# LinearRegression           0.632346
# KNeighborsRegressor        0.612454
# SVR                        0.629544
# MLPRegressor               0.578973  ), ('Embeddings',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.170406               0.336995
# DecisionTreeRegressor                   0.238972               0.379232
# RandomForestRegressor                   0.161184               0.323493
# GradientBoostingRegressor               0.180552               0.339858
# AdaBoostRegressor                       0.167832               0.329176
# XGBRegressor                            0.206516               0.349788
# ExtraTreesRegressor                     0.163785               0.327675
# LinearRegression                        0.215530               0.370999
# KNeighborsRegressor                     0.177825               0.331929
# SVR                                     0.186623               0.347102
# MLPRegressor                            0.519958               0.618302
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.412803              0.564612
# DecisionTreeRegressor                    0.488847              0.389428
# RandomForestRegressor                    0.401477              0.588176
# GradientBoostingRegressor                0.424914              0.538691
# AdaBoostRegressor                        0.409673              0.571191
# XGBRegressor                             0.454441              0.472351
# ExtraTreesRegressor                      0.404704              0.581529
# LinearRegression                         0.464252              0.449321
# KNeighborsRegressor                      0.421692              0.545659
# SVR                                      0.431999              0.523179
# MLPRegressor                             0.721081             -0.328490
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.757037               0.743458
# DecisionTreeRegressor                   0.698068               0.683403
# RandomForestRegressor                   0.768768               0.744943
# GradientBoostingRegressor               0.748058               0.722293
# AdaBoostRegressor                       0.758646               0.750486
# XGBRegressor                            0.707723               0.689925
# ExtraTreesRegressor                     0.765208               0.742462
# LinearRegression                        0.706833               0.692302
# KNeighborsRegressor                     0.739904               0.727627
# SVR                                     0.726337               0.713287
# MLPRegressor                            0.707276               0.699418
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.248183  0.363983   0.498179  0.462678  0.681579
# DecisionTreeRegressor      0.271932  0.394314   0.521471  0.411260  0.650657
# RandomForestRegressor      0.228765  0.344990   0.478294  0.504716  0.710435
# GradientBoostingRegressor  0.240182  0.353769   0.490084  0.479999  0.693640
# AdaBoostRegressor          0.215954  0.344488   0.464709  0.532453  0.731031
# XGBRegressor               0.231137  0.349493   0.480767  0.499582  0.707025
# ExtraTreesRegressor        0.212701  0.325147   0.461195  0.539496  0.736287
# LinearRegression           0.259240  0.362942   0.509156  0.438737  0.662818
# KNeighborsRegressor        0.258263  0.346297   0.508196  0.440854  0.667829
# SVR                        0.238770  0.319843   0.488641  0.483057  0.700128
# MLPRegressor               0.676057  0.735297   0.822227 -0.463683  0.591883
#
#                            Test SCC
# LGBMRegressor              0.602367
# DecisionTreeRegressor      0.531624
# RandomForestRegressor      0.614975
# GradientBoostingRegressor  0.567346
# AdaBoostRegressor          0.659802
# XGBRegressor               0.594383
# ExtraTreesRegressor        0.628423
# LinearRegression           0.625482
# KNeighborsRegressor        0.586398
# SVR                        0.626182
# MLPRegressor               0.552077  ), ('Fingerprints',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.147760               0.304641
# DecisionTreeRegressor                   0.289676               0.423661
# RandomForestRegressor                   0.141792               0.295522
# GradientBoostingRegressor               0.155116               0.311020
# AdaBoostRegressor                       0.152585               0.311924
# XGBRegressor                            0.182745               0.337175
# ExtraTreesRegressor                     0.138237               0.297908
# LinearRegression                        0.172601               0.331827
# KNeighborsRegressor                     0.144874               0.302436
# SVR                                     0.147022               0.303863
# MLPRegressor                            0.565028               0.654491
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.384395              0.622474
# DecisionTreeRegressor                    0.538216              0.259879
# RandomForestRegressor                    0.376553              0.637722
# GradientBoostingRegressor                0.393848              0.603679
# AdaBoostRegressor                        0.390621              0.610147
# XGBRegressor                             0.427487              0.533087
# ExtraTreesRegressor                      0.371803              0.646804
# LinearRegression                         0.415453              0.559005
# KNeighborsRegressor                      0.380623              0.629848
# SVR                                      0.383434              0.624359
# MLPRegressor                             0.751684             -0.443646
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.789822               0.783412
# DecisionTreeRegressor                   0.627204               0.584480
# RandomForestRegressor                   0.799374               0.788119
# GradientBoostingRegressor               0.782717               0.771215
# AdaBoostRegressor                       0.783511               0.764530
# XGBRegressor                            0.746718               0.733918
# ExtraTreesRegressor                     0.804451               0.795014
# LinearRegression                        0.755506               0.745889
# KNeighborsRegressor                     0.794347               0.779814
# SVR                                     0.790909               0.790022
# MLPRegressor                            0.768759               0.763189
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.246777  0.352395   0.496767  0.465720  0.687319
# DecisionTreeRegressor      0.184418  0.311757   0.429439  0.600729  0.775777
# RandomForestRegressor      0.214341  0.319853   0.462970  0.535945  0.732457
# GradientBoostingRegressor  0.217020  0.317298   0.465854  0.530145  0.730716
# AdaBoostRegressor          0.204742  0.318904   0.452485  0.556727  0.746545
# XGBRegressor               0.216763  0.322244   0.465578  0.530702  0.734612
# ExtraTreesRegressor        0.212917  0.314888   0.461429  0.539029  0.734440
# LinearRegression           0.223108  0.337092   0.472344  0.516964  0.719215
# KNeighborsRegressor        0.253985  0.354634   0.503969  0.450115  0.674979
# SVR                        0.253808  0.341079   0.503794  0.450498  0.680447
# MLPRegressor               0.771088  0.821578   0.878116 -0.669427  0.630529
#
#                            Test SCC
# LGBMRegressor              0.634447
# DecisionTreeRegressor      0.717568
# RandomForestRegressor      0.657001
# GradientBoostingRegressor  0.636128
# AdaBoostRegressor          0.693983
# XGBRegressor               0.680675
# ExtraTreesRegressor        0.683197
# LinearRegression           0.639210
# KNeighborsRegressor        0.605309
# SVR                        0.620298
# MLPRegressor               0.587378  )])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import os
import pandas as pd

plots_dir = '/home/users/akshay/PCPpred/RRCK/results/Ablation/plots'
os.makedirs(plots_dir, exist_ok=True)
  	 	 	 						 		 	 	 	 	
actual_values = {
    "Test MSE": 0.206275,
    "Test MAE": 0.320572,
    "Test RMSE": 0.454175,
    "Test R2": 0.553408,
    "Test PCC": 0.744065,
    "Test SCC": 0.668628
}

metrics = ["Test MSE", "Test MAE", "Test RMSE", "Test R2", "Test PCC", "Test SCC"]
num_bars = len(ablation_results)
colors = cm.get_cmap('tab10', num_bars).colors

for metric in metrics:
    metric_data = {label: df.loc["AdaBoostRegressor", metric] for label, df in ablation_results.items()}
    metric_series = pd.Series(metric_data)

    fig, ax = plt.subplots(figsize=(5, 7))
    bars = ax.bar(metric_series.index, metric_series.values, color=colors, edgecolor='black', linewidth=1.2)

    y_max = metric_series.max()
    if metric == 'Test R2':
        ax.set_ylim(0.0, y_max + 0.2)
    if metric == 'Test MSE':
        ax.set_ylim(0.0, y_max + 0.02)
    if metric == 'Test RMSE':
        ax.set_ylim(0.0, y_max + 0.07)
    if metric == 'Test PCC':
        ax.set_ylim(0.0, y_max + 0.2)
    if metric == 'Test SCC':
        ax.set_ylim(0.0, y_max + 0.2)
    if metric == 'Test MAE':
        ax.set_ylim(0.0, y_max + 0.05)

    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

    actual_value = actual_values[metric]
    ax.axhline(y=actual_value, color='red', linestyle='--', linewidth=1.5,
               label=f'Actual {metric.split()[-1]}: {actual_value:.4f}')

    ax.legend(loc='upper right', fontsize=9)

    ax.set_title(f'{metric}', fontsize=14)
    ax.set_xlabel('Ablation Study', fontsize=10)
    ax.set_ylabel(metric, fontsize=10)
    ax.set_xticks(range(len(metric_series)))
    ax.set_xticklabels(metric_series.index, rotation=55, ha='right')
    ax.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()

    save_path = os.path.join(plots_dir, f"{metric.replace(' ', '_')}.png")
    plt.savefig(save_path, dpi=300)
    print(f"Saved plot for {metric} to {save_path}")
    plt.show()
# Out:
# /tmp/ipykernel_1556793/417616449.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap('tab10', num_bars).colors
# Saved plot for Test MSE to /home/users/akshay/PCPpred/RRCK/results/Ablation/plots/Test_MSE.png
# Saved plot for Test MAE to /home/users/akshay/PCPpred/RRCK/results/Ablation/plots/Test_MAE.png
# Saved plot for Test RMSE to /home/users/akshay/PCPpred/RRCK/results/Ablation/plots/Test_RMSE.png
# Saved plot for Test R2 to /home/users/akshay/PCPpred/RRCK/results/Ablation/plots/Test_R2.png
# Saved plot for Test PCC to /home/users/akshay/PCPpred/RRCK/results/Ablation/plots/Test_PCC.png
# Saved plot for Test SCC to /home/users/akshay/PCPpred/RRCK/results/Ablation/plots/Test_SCC.png
