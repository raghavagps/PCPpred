# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/users/akshay/PCPpred/MDCK/data/CycPeptMPDB_Peptide_Assay_MDCK (1).csv')
df.shape
# Out:
# (64, 247)

# %%
last_id = df['ID'].max()
print('last_id: ', last_id)
# Out:
# last_id:  8346

# %%
#Step 1: Removing unreliable datapoints (datapoints with Permeability value <= -10) and selecting the required Columns
df = df[df['MDCK'] > -10]
selected_columns = ['ID', 'SMILES', 'MDCK', 'Sequence', 'MolWt']
new_df = df[selected_columns]
new_df.shape
# Out:
# (64, 5)

# %%
new_df.columns = ['ID', 'SMILES', 'Permeability', 'Sequence', 'MolWt']

# %%
new_df.head(10)
# Out:
#      ID                                             SMILES  Permeability  \
# 0  1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...         -5.70
# 1  1018  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)N(C)C(=O...         -4.96
# 2  1107  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...         -4.61
# 3  1108  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...         -5.18
# 4  1109  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N(C)C(...         -6.12
# 5  1110  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)N(C)C(=O)[C@H]...         -4.73
# 6  1111  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](CC(C...         -6.22
# 7  1112  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](C)NC(=O)[...         -6.17
# 8  1113  CC(C)C[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)[C@@H](Cc2...         -5.82
# 9  1114  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...         -4.94
#
#                                             Sequence     MolWt
# 0                   ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 1            ['L', 'Me_dL', 'meL', 'L', 'dP', 'meY']   755.014
# 2  ['L', 'meL', 'L', 'Me_dA', 'meA', 'L', 'meL', ...  1047.438
# 3  ['L', 'meA', 'L', 'Me_dA', 'meA', 'L', 'meA', ...   963.276
# 4  ['A', 'meA', 'A', 'Me_dA', 'meA', 'A', 'meA', ...   794.952
# 5  ['L', 'meL', 'L', 'Sar', 'P', 'L', 'meL', 'L',...  1043.406
# 6  ['L', 'meA', 'L', 'Sar', 'P', 'L', 'meA', 'L',...   959.244
# 7  ['A', 'meA', 'A', 'Sar', 'P', 'A', 'meA', 'A',...   790.920
# 8  ['L', 'meA', 'L', 'Me_dF', 'P', 'L', 'meA', 'L...  1139.494
# 9  ['L', 'meA', 'L', 'dP', 'meF', 'L', 'meA', 'L'...  1139.494

# %%
#Step 2: curating duplicate dapaoints based on SMILES representation
duplicates = new_df[new_df.duplicated(subset='SMILES', keep=False)]
non_duplicates = new_df[~new_df.duplicated(subset='SMILES', keep=False)]
print("DataFrame with duplicates:")
print(duplicates)
print("\nDataFrame without duplicates:")
print(non_duplicates)
duplicates.to_csv('/home/users/akshay/PCPpred/MDCK/data/duplicates_MDCK.csv', index=False)
# Out:
# DataFrame with duplicates:
# Empty DataFrame
# Columns: [ID, SMILES, Permeability, Sequence, MolWt]
# Index: []
#
# DataFrame without duplicates:
#       ID                                             SMILES  Permeability  \
# 0   1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...     -5.700000
# 1   1018  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)N(C)C(=O...     -4.960000
# 2   1107  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -4.610000
# 3   1108  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -5.180000
# 4   1109  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N(C)C(...     -6.120000
# ..   ...                                                ...           ...
# 59  8342  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.897175
# 60  8343  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -6.405218
# 61  8344  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.917901
# 62  8345  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC)C(=O)N(CC(C)...     -7.534591
# 63  8346  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -7.562400
#
#                                              Sequence     MolWt
# 0                    ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 1             ['L', 'Me_dL', 'meL', 'L', 'dP', 'meY']   755.014
# 2   ['L', 'meL', 'L', 'Me_dA', 'meA', 'L', 'meL', ...  1047.438
# 3   ['L', 'meA', 'L', 'Me_dA', 'meA', 'L', 'meA', ...   963.276
# 4   ['A', 'meA', 'A', 'Me_dA', 'meA', 'A', 'meA', ...   794.952
# ..                                                ...       ...
# 59  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 60  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'L', ...   996.327
# 61  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 62  ['Abu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL', ...   996.327
# 63  ['dAbu', 'iBu_Gly', 'L', 'dP', 'meA', 'dL', 'M...  1008.338
#
# [64 rows x 5 columns]

# %%
duplicates = new_df[new_df.duplicated(subset='SMILES', keep=False)]

non_duplicates = new_df[~new_df.duplicated(subset='SMILES', keep=False)]
#Permeability and MolWt of duplicate SMILES were averaged, and Most abundandant sequence was chosen
grouped_duplicates = duplicates.groupby('SMILES').agg(
    Permeability=('Permeability', 'mean'),   
    MolWt=('MolWt', 'mean'),   
    Sequence=('Sequence', lambda x: x.mode()[0]), 
).reset_index()

#Unique ID's were given to these curated datapoints, where ID's start from the last documented id in CycPeptMPDB_Peptide_Assay_PAMPA (5)
grouped_duplicates['ID'] = range(last_id + 1, last_id + 1 + len(grouped_duplicates))

grouped_duplicates = grouped_duplicates[['ID', 'SMILES', 'Permeability', 'Sequence', 'MolWt']]

non_duplicates_ordered = non_duplicates[['ID', 'SMILES', 'Permeability', 'Sequence', 'MolWt']]
merged_df = pd.concat([non_duplicates_ordered, grouped_duplicates], ignore_index=True)

print("DataFrame with processed duplicates:")
print(grouped_duplicates)

print("\nDataFrame without duplicates:")
print(non_duplicates)

print("Merged DataFrame:")
print(merged_df)

grouped_duplicates.to_csv('/home/users/akshay/PCPpred/MDCK/data/grouped_duplicates_MDCK.csv', index=False)
non_duplicates.to_csv('/home/users/akshay/PCPpred/MDCK/data/non_duplicates_MDCK.csv', index=False)
merged_df.to_csv('/home/users/akshay/PCPpred/MDCK/data/CycPeptMPDB_data_Main_MDCK.csv', index=False)
# Out:
# DataFrame with processed duplicates:
# Empty DataFrame
# Columns: [ID, SMILES, Permeability, Sequence, MolWt]
# Index: []
#
# DataFrame without duplicates:
#       ID                                             SMILES  Permeability  \
# 0   1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...     -5.700000
# 1   1018  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)N(C)C(=O...     -4.960000
# 2   1107  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -4.610000
# 3   1108  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -5.180000
# 4   1109  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N(C)C(...     -6.120000
# ..   ...                                                ...           ...
# 59  8342  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.897175
# 60  8343  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -6.405218
# 61  8344  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.917901
# 62  8345  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC)C(=O)N(CC(C)...     -7.534591
# 63  8346  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -7.562400
#
#                                              Sequence     MolWt
# 0                    ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 1             ['L', 'Me_dL', 'meL', 'L', 'dP', 'meY']   755.014
# 2   ['L', 'meL', 'L', 'Me_dA', 'meA', 'L', 'meL', ...  1047.438
# 3   ['L', 'meA', 'L', 'Me_dA', 'meA', 'L', 'meA', ...   963.276
# 4   ['A', 'meA', 'A', 'Me_dA', 'meA', 'A', 'meA', ...   794.952
# ..                                                ...       ...
# 59  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 60  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'L', ...   996.327
# 61  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 62  ['Abu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL', ...   996.327
# 63  ['dAbu', 'iBu_Gly', 'L', 'dP', 'meA', 'dL', 'M...  1008.338
#
# [64 rows x 5 columns]
# Merged DataFrame:
#       ID                                             SMILES  Permeability  \
# 0   1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...     -5.700000
# 1   1018  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)N(C)C(=O...     -4.960000
# 2   1107  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -4.610000
# 3   1108  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -5.180000
# 4   1109  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N(C)C(...     -6.120000
# ..   ...                                                ...           ...
# 59  8342  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.897175
# 60  8343  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -6.405218
# 61  8344  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.917901
# 62  8345  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC)C(=O)N(CC(C)...     -7.534591
# 63  8346  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -7.562400
#
#                                              Sequence     MolWt
# 0                    ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 1             ['L', 'Me_dL', 'meL', 'L', 'dP', 'meY']   755.014
# 2   ['L', 'meL', 'L', 'Me_dA', 'meA', 'L', 'meL', ...  1047.438
# 3   ['L', 'meA', 'L', 'Me_dA', 'meA', 'L', 'meA', ...   963.276
# 4   ['A', 'meA', 'A', 'Me_dA', 'meA', 'A', 'meA', ...   794.952
# ..                                                ...       ...
# 59  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 60  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'L', ...   996.327
# 61  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 62  ['Abu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL', ...   996.327
# 63  ['dAbu', 'iBu_Gly', 'L', 'dP', 'meA', 'dL', 'M...  1008.338
#
# [64 rows x 5 columns]

# %%
#Step 3: Splitting the Main dataset into Train and Test in ration 0.8:0.2
df = pd.read_csv('/home/users/akshay/PCPpred/MDCK/data/CycPeptMPDB_data_Main_MDCK.csv')
df
# Out:
#       ID                                             SMILES  Permeability  \
# 0   1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...     -5.700000
# 1   1018  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)N(C)C(=O...     -4.960000
# 2   1107  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -4.610000
# 3   1108  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -5.180000
# 4   1109  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N(C)C(...     -6.120000
# ..   ...                                                ...           ...
# 59  8342  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.897175
# 60  8343  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -6.405218
# 61  8344  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.917901
# 62  8345  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC)C(=O)N(CC(C)...     -7.534591
# 63  8346  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -7.562400
#
#                                              Sequence     MolWt
# 0                    ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 1             ['L', 'Me_dL', 'meL', 'L', 'dP', 'meY']   755.014
# 2   ['L', 'meL', 'L', 'Me_dA', 'meA', 'L', 'meL', ...  1047.438
# 3   ['L', 'meA', 'L', 'Me_dA', 'meA', 'L', 'meA', ...   963.276
# 4   ['A', 'meA', 'A', 'Me_dA', 'meA', 'A', 'meA', ...   794.952
# ..                                                ...       ...
# 59  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 60  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'L', ...   996.327
# 61  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 62  ['Abu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL', ...   996.327
# 63  ['dAbu', 'iBu_Gly', 'L', 'dP', 'meA', 'dL', 'M...  1008.338
#
# [64 rows x 5 columns]

# %%
#Main dataset is sorted based on Molecular weight in descending order
df_main = df.sort_values(by='MolWt', ascending= False)
df_main
# Out:
#       ID                                             SMILES  Permeability  \
# 15  1120  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...         -6.30
# 9   1114  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...         -4.94
# 8   1113  CC(C)C[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)[C@@H](Cc2...         -5.82
# 12  1117  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H]2CCCN...         -5.65
# 14  1119  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...         -6.25
# ..   ...                                                ...           ...
# 0   1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...         -5.70
# 19  1842  CC[C@H](C)[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@H...         -4.40
# 17  1840  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](C...         -4.48
# 21  1844  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](C...         -5.10
# 23  1846  CC[C@H](C)[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@H...         -4.82
#
#                                              Sequence     MolWt
# 15  ['L', 'meA', 'L', 'Me_dL', 'meF', 'L', 'meA', ...  1199.634
# 9   ['L', 'meA', 'L', 'dP', 'meF', 'L', 'meA', 'L'...  1139.494
# 8   ['L', 'meA', 'L', 'Me_dF', 'P', 'L', 'meA', 'L...  1139.494
# 12  ['L', 'meF', 'L', 'dP', 'meA', 'L', 'meF', 'L'...  1139.494
# 14  ['L', 'meA', 'L', 'Me_dA', 'meF', 'L', 'meA', ...  1115.472
# ..                                                ...       ...
# 0                    ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 19                     ['L', 'F', 'P', 'L', 'L', 'I']   696.934
# 17                   ['L', 'dF', 'P', 'L', 'dL', 'L']   696.934
# 21                  ['L', 'dF', 'dP', 'L', 'dL', 'L']   696.934
# 23                    ['L', 'F', 'dP', 'L', 'L', 'I']   696.934
#
# [64 rows x 5 columns]

# %%
df_main['MolWt']
# Out:
# 15    1199.634
# 9     1139.494
# 8     1139.494
# 12    1139.494
# 14    1115.472
#         ...
# 0      712.933
# 19     696.934
# 17     696.934
# 21     696.934
# 23     696.934
# Name: MolWt, Length: 64, dtype: float64

# %%
#Every fifth datapoint is allocated to test set and remaining datapoints to Train set
test_mask = np.arange(len(df_main)) % 5 == 0
test_df = df_main[test_mask]
test_df.shape
# Out:
# (13, 5)

# %%
train_df = df_main[~test_mask]
train_df.shape
# Out:
# (51, 5)

# %%
print(train_df["Permeability"].max())
print(train_df["Permeability"].min())
print(train_df.shape)
# Out:
# -4.41
# -7.698970004
# (51, 5)

# %%
print(test_df["Permeability"].max())
print(test_df["Permeability"].min())
print(test_df.shape)
# Out:
# -4.4
# -7.534591416
# (13, 5)

# %%
test_df.to_csv("/home/users/akshay/PCPpred/MDCK/data/Test_MDCK.csv",index=False)
train_df.to_csv("/home/users/akshay/PCPpred/MDCK/data/Train_MDCK.csv",index=False)

# %%
train_df
# Out:
#       ID                                             SMILES  Permeability  \
# 9   1114  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...     -4.940000
# 8   1113  CC(C)C[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)[C@@H](Cc2...     -5.820000
# 12  1117  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H]2CCCN...     -5.650000
# 14  1119  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...     -6.250000
# 27  2428  CCN1CC(=O)N[C@@H](CC(C)C)C(=O)N(C)[C@@H](C)C(=...     -5.510000
# 30  2446  CCN1CC(=O)N[C@@H](CC(C)C)C(=O)N2CCC[C@@H]2C(=O...     -6.400000
# 29  2445  CCN1CC(=O)N[C@@H](CC(C)C)C(=O)N2CCC[C@@H]2C(=O...     -4.820000
# 26  2427  CCN1CC(=O)N[C@@H](CC(C)C)C(=O)N(C)[C@@H](C)C(=...     -4.610000
# 51  8145  CCC[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](CC(C)C)...     -5.744727
# 2   1107  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -4.610000
# 11  1116  CC(C)C[C@@H]1NC(=O)[C@H](C(C)C)N(C)C(=O)[C@H]2...     -5.220000
# 5   1110  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)N(C)C(=O)[C@H]...     -4.730000
# 43  8121  CCC[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](CC(C)C)...     -5.289037
# 32  5836  CC(=O)N1CCC[C@H]1C(=O)N(C)[C@@H](CC(C)C)C(=O)N...     -4.580000
# 33  6187  CC(=O)N1CCC[C@@H]1C(=O)N(C)[C@H](CC(C)C)C(=O)N...     -5.120000
# 38  6584  CC(=O)N1CCC[C@H]1C(=O)N(C)[C@H](CC(C)C)C(=O)N[...     -5.320000
# 37  6571  CC(=O)N1CCC[C@H]1C(=O)N(C)[C@H](CC(C)C)C(=O)N[...     -4.970000
# 31  5803  CC(=O)N1CCC[C@H]1C(=O)N(C)[C@@H](CC(C)C)C(=O)N...     -6.300000
# 25  2422  CCN1CC(=O)N[C@@H](CC(C)C)C(=O)N(C)[C@@H](C)C(=...     -6.400000
# 28  2440  CCN1CC(=O)N[C@@H](CC(C)C)C(=O)N2CCC[C@@H]2C(=O...     -6.520000
# 49  8140  CCC[C@H]1C(=O)N[C@@H](CC)C(=O)N(C)[C@@H](C)C(=...     -5.185752
# 46  8131  CCC[C@@H]1NC(=O)CN(CCC)C(=O)[C@H](CC(C)C)NC(=O...     -5.501689
# 63  8346  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -7.562400
# 57  8184  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(C)[C@@...     -7.698970
# 36  6505  CC(=O)N1CCC[C@H]1C(=O)N(C)[C@H](CC(C)C)C(=O)N[...     -6.050000
# 59  8342  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.897175
# 55  8160  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(C)[C@@...     -5.193142
# 58  8341  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -6.321123
# 61  8344  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -5.917901
# 60  8343  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(CC(C)C...     -6.405218
# 54  8156  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(C)[C@@...     -6.065502
# 52  8150  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(C)[C@@...     -5.903090
# 53  8152  CCOC(=O)[C@@H]1CSCC(=O)N[C@H](CC)C(=O)N(C)[C@@...     -5.044793
# 41  8116  CCCN1CC(=O)N[C@@H](CC)C(=O)N(C)[C@@H](C)C(=O)N...     -5.402305
# 45  8128  CCCN1CC(=O)N[C@@H](CC(C)C)C(=O)N2CCC[C@@H]2C(=...     -5.585027
# 48  8138  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC(C)C)C(=O)N(C...     -5.129011
# 39  6666  CC(=O)N1CCC[C@@H]1C(=O)N(C)[C@H](CC(C)C)C(=O)N...     -6.400000
# 10  1115  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H]2CCCN...     -5.190000
# 44  8126  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC(C)C)C(=O)N(C...     -5.752027
# 40  8114  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC(C)C)C(=O)N(C...     -5.344862
# 6   1111  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](CC(C...     -6.220000
# 4   1109  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N(C)C(...     -6.120000
# 7   1112  C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](C)NC(=O)[...     -6.170000
# 1   1018  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)N(C)C(=O...     -4.960000
# 22  1845  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](C...     -4.960000
# 24  1847  CC[C@H](C)[C@@H]1NC(=O)[C@@H](CC(C)C)NC(=O)[C@...     -4.740000
# 18  1841  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](C...     -4.410000
# 0   1017  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C...     -5.700000
# 17  1840  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](C...     -4.480000
# 21  1844  CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](C...     -5.100000
# 23  1846  CC[C@H](C)[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@H...     -4.820000
#
#                                              Sequence     MolWt
# 9   ['L', 'meA', 'L', 'dP', 'meF', 'L', 'meA', 'L'...  1139.494
# 8   ['L', 'meA', 'L', 'Me_dF', 'P', 'L', 'meA', 'L...  1139.494
# 12  ['L', 'meF', 'L', 'dP', 'meA', 'L', 'meF', 'L'...  1139.494
# 14  ['L', 'meA', 'L', 'Me_dA', 'meF', 'L', 'meA', ...  1115.472
# 27  ['L', 'dP', 'Mono38', 'L', 'meA', 'F', 'dP', '...  1091.406
# 30  ['L', 'dP', 'meL', 'A', 'Mono38', 'F', 'dP', '...  1091.406
# 29  ['L', 'dP', 'meL', 'A', 'cHexCH2_Gly', 'F', 'd...  1089.434
# 26  ['L', 'dP', 'cHexCH2_Gly', 'L', 'meA', 'F', 'd...  1089.434
# 51  ['L', 'meA', 'Nva', 'dP', 'Me_Abu', 'Cha', 'me...  1048.403
# 2   ['L', 'meL', 'L', 'Me_dA', 'meA', 'L', 'meL', ...  1047.438
# 11  ['L', 'meA', 'L', 'dP', 'meV', 'L', 'meA', 'L'...  1043.406
# 5   ['L', 'meL', 'L', 'Sar', 'P', 'L', 'meL', 'L',...  1043.406
# 43  ['L', 'meA', 'Nva', 'dP', 'Et_Gly', 'Cha', 'me...  1034.376
# 32  ['ac-', 'P', 'meL', 'T', 'Me_dL', 'meL', 'L', ...  1030.363
# 33  ['ac-', 'dP', 'Me_dL', 'T', 'Me_dL', 'meL', 'm...  1030.363
# 38  ['ac-', 'P', 'Me_dL', 'T', 'meL', 'L', 'Me_dL'...  1030.363
# 37  ['ac-', 'P', 'Me_dL', 'T', 'dL', 'meL', 'dL', ...  1016.336
# 31  ['ac-', 'P', 'meL', 'T', 'meL', 'L', 'meL', 'A...  1016.336
# 25  ['L', 'dP', 'Mono38', 'L', 'meA', 'A', 'dP', '...  1015.308
# 28  ['L', 'dP', 'meL', 'A', 'Mono38', 'A', 'dP', '...  1015.308
# 49  ['L', 'meA', 'L', 'dP', 'Me_Nva', 'Abu', 'meA'...  1008.338
# 46  ['L', 'Pr_Gly', 'Nva', 'dP', 'meA', 'L', 'meA'...  1008.338
# 63  ['dAbu', 'iBu_Gly', 'L', 'dP', 'meA', 'dL', 'M...  1008.338
# 57  ['dAbu', 'meA', 'L', 'dP', 'iBu_Gly', 'dL', 'M...  1008.338
# 36  ['ac-', 'P', 'Me_dL', 'T', 'dL', 'meL', 'dL', ...  1002.309
# 59  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 55  ['dAbu', 'meA', 'L', 'Me_dA', 'iBu_Gly', 'dL',...   996.327
# 58  ['dAbu', 'iBu_Gly', 'dL', 'Me_dA', 'meA', 'dL'...   996.327
# 61  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL',...   996.327
# 60  ['dAbu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'L', ...   996.327
# 54  ['dAbu', 'meA', 'L', 'Me_dA', 'iBu_Gly', 'L', ...   996.327
# 52  ['dAbu', 'meA', 'dL', 'Me_dA', 'iBu_Gly', 'dL'...   996.327
# 53  ['dAbu', 'meA', 'L', 'Me_dA', 'iBu_Gly', 'dL',...   996.327
# 41  ['L', 'meA', 'L', 'dP', 'Pr_Gly', 'Abu', 'meA'...   994.311
# 45  ['L', 'Pr_Gly', 'L', 'dP', 'meA', 'Abu', 'meA'...   994.311
# 48  ['L', 'meA', 'L', 'dP', 'Me_Abu', 'Abu', 'meA'...   994.311
# 39  ['ac-', 'dP', 'Me_dL', 'T', 'dL', 'dL', 'L', '...   988.282
# 10  ['L', 'meA', 'L', 'dP', 'meA', 'L', 'meA', 'L'...   987.298
# 44  ['L', 'Et_Gly', 'L', 'dP', 'meA', 'Abu', 'meA'...   980.284
# 40  ['L', 'meA', 'L', 'dP', 'Et_Gly', 'Abu', 'meA'...   980.284
# 6   ['L', 'meA', 'L', 'Sar', 'P', 'L', 'meA', 'L',...   959.244
# 4   ['A', 'meA', 'A', 'Me_dA', 'meA', 'A', 'meA', ...   794.952
# 7   ['A', 'meA', 'A', 'Sar', 'P', 'A', 'meA', 'A',...   790.920
# 1             ['L', 'Me_dL', 'meL', 'L', 'dP', 'meY']   755.014
# 22                  ['L', 'dF', 'dP', 'F', 'dL', 'L']   730.951
# 24                  ['L', 'dF', 'dP', 'F', 'dL', 'I']   730.951
# 18                   ['L', 'dF', 'P', 'F', 'dL', 'L']   730.951
# 0                    ['L', 'dL', 'L', 'L', 'dP', 'Y']   712.933
# 17                   ['L', 'dF', 'P', 'L', 'dL', 'L']   696.934
# 21                  ['L', 'dF', 'dP', 'L', 'dL', 'L']   696.934
# 23                    ['L', 'F', 'dP', 'L', 'L', 'I']   696.934

# %%
test_df
# Out:
#       ID                                             SMILES  Permeability  \
# 15  1120  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)N(C)C(=O)[C...     -6.300000
# 13  1118  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](Cc2...     -5.350000
# 16  1121  CC(C)C[C@@H]1NC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H]...     -6.200000
# 47  8133  CCC[C@@H]1NC(=O)CN(CC)C(=O)[C@H](CC(C)C)NC(=O)...     -5.355561
# 50  8143  CCC[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](CC(C)C)...     -5.406714
# 42  8119  CCC[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@H](CC(C)C)...     -5.073658
# 35  6496  CC(=O)N1CCC[C@H]1C(=O)N(C)[C@H](CC(C)C)C(=O)N[...     -4.860000
# 56  8168  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC)C(=O)N(C)[C@...     -6.031517
# 62  8345  CCOC(=O)[C@@H]1CSCC(=O)N[C@@H](CC)C(=O)N(CC(C)...     -7.534591
# 34  6423  CC(=O)N1CCC[C@@H]1C(=O)N(C)[C@@H](CC(C)C)C(=O)...     -6.300000
# 3   1108  CC(C)C[C@@H]1NC(=O)[C@H](C)N(C)C(=O)[C@@H](C)N...     -5.180000
# 20  1843  CC[C@H](C)[C@@H]1NC(=O)[C@@H](CC(C)C)NC(=O)[C@...     -4.400000
# 19  1842  CC[C@H](C)[C@@H]1NC(=O)[C@H](CC(C)C)NC(=O)[C@H...     -4.400000
#
#                                              Sequence     MolWt
# 15  ['L', 'meA', 'L', 'Me_dL', 'meF', 'L', 'meA', ...  1199.634
# 13  ['L', 'meA', 'L', 'Me_dF', 'meA', 'L', 'meA', ...  1115.472
# 16  ['L', 'A', 'L', 'dP', 'F', 'L', 'A', 'L', 'dP'...  1083.386
# 47  ['L', 'Et_Gly', 'Nva', 'dP', 'meA', 'Cha', 'me...  1034.376
# 50  ['L', 'meA', 'Nva', 'dP', 'Me_Nva', 'L', 'meA'...  1022.365
# 42  ['L', 'meA', 'Nva', 'dP', 'Pr_Gly', 'L', 'meA'...  1008.338
# 35  ['ac-', 'P', 'Me_dL', 'T', 'dL', 'L', 'dL', 'M...  1002.309
# 56  ['Abu', 'meA', 'L', 'Me_dA', 'iBu_Gly', 'dL', ...   996.327
# 62  ['Abu', 'iBu_Gly', 'L', 'Me_dA', 'meA', 'dL', ...   996.327
# 34  ['ac-', 'dP', 'meL', 'T', 'dL', 'dL', 'L', 'A'...   988.282
# 3   ['L', 'meA', 'L', 'Me_dA', 'meA', 'L', 'meA', ...   963.276
# 20                   ['L', 'dF', 'P', 'F', 'dL', 'I']   730.951
# 19                     ['L', 'F', 'P', 'L', 'L', 'I']   696.934

# %%
import pandas as pd

df = pd.read_csv('/home/users/akshay/PCPpred/MDCK/data/Train_MDCK.csv')

with open('/home/users/akshay/PCPpred/MDCK/data/Train_MDCK.smi', 'w') as f:
    for _, row in df.iterrows():
        smiles = row['SMILES']
        id = row['ID']
        f.write(f"{smiles} {id}\n")
print("train.smi file has been created successfully.")
# Out:
# train.smi file has been created successfully.

# %%
df = pd.read_csv('/home/users/akshay/PCPpred/MDCK/data/Test_MDCK.csv')

with open('/home/users/akshay/PCPpred/MDCK/data/Test_MDCK.smi', 'w') as f:
    for _, row in df.iterrows():
        smiles = row['SMILES']
        id = row['ID']
        f.write(f"{smiles} {id}\n")
print("test.smi file has been created successfully.")
# Out:
# test.smi file has been created successfully.
