# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.cm as cm
import numpy as np

dataframes = ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)',
              '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']

ablation_results = {}

for ablation_idx in range(len(dataframes)):
    print(f"========== Ablation: Excluding feature at index {ablation_idx} ==========")
    excluded_dataframe = dataframes[ablation_idx]
    print('Excluded dataframe:', excluded_dataframe)

    ablated_dataframes = [pair for i, pair in enumerate(dataframes) if i != ablation_idx]
    print('Ablated index', ablation_idx, '----->', 'Ablated_dataframes', ablated_dataframes)
# Out:
# ========== Ablation: Excluding feature at index 0 ==========
# Excluded dataframe: (df_desc_train, df_desc_test)
# Ablated index 0 -----> Ablated_dataframes ['(df_fp_train, df_fp_test)', '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 1 ==========
# Excluded dataframe: (df_fp_train, df_fp_test)
# Ablated index 1 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 2 ==========
# Excluded dataframe: (df_emb_train, df_emb_test)
# Ablated index 2 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 3 ==========
# Excluded dataframe: (df_atomic_train, df_atomic_test)
# Ablated index 3 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)', '(df_emb_train, df_emb_test)']

# %%
ablation_result_dir = '/home/users/akshay/PCPpred/Caco2/results/Ablation/'

ablation_results = {}
for filename in os.listdir(ablation_result_dir):
    if filename.endswith('.csv'):
        ablation_label = filename.replace('.csv', '').replace("Ablation_", "")
        print(ablation_label)
        file_path = os.path.join(ablation_result_dir, filename)
    
        ablation_results[ablation_label] = pd.read_csv(file_path, index_col=0)


ablation_results
# Out:
# Descriptor
# Atomic
# Embeddings
# Fingerprints
# {'Descriptor':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.139787               0.282037
#  DecisionTreeRegressor                   0.273349               0.402000
#  RandomForestRegressor                   0.133021               0.274761
#  GradientBoostingRegressor               0.135888               0.280679
#  AdaBoostRegressor                       0.144500               0.296127
#  XGBRegressor                            0.154141               0.299476
#  ExtraTreesRegressor                     0.131427               0.272303
#  LinearRegression                        0.142635               0.290935
#  KNeighborsRegressor                     0.148939               0.293499
#  SVR                                     0.133759               0.278530
#  MLPRegressor                            0.173988               0.323234
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.373881              0.781883
#  DecisionTreeRegressor                    0.522828              0.573480
#  RandomForestRegressor                    0.364720              0.792441
#  GradientBoostingRegressor                0.368631              0.787966
#  AdaBoostRegressor                        0.380132              0.774529
#  XGBRegressor                             0.392608              0.759486
#  ExtraTreesRegressor                      0.362528              0.794929
#  LinearRegression                         0.377670              0.777440
#  KNeighborsRegressor                      0.385927              0.767602
#  SVR                                      0.365731              0.791289
#  MLPRegressor                             0.417119              0.728518
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.884445               0.873364
#  DecisionTreeRegressor                   0.783268               0.775736
#  RandomForestRegressor                   0.890196               0.880727
#  GradientBoostingRegressor               0.887826               0.876628
#  AdaBoostRegressor                       0.880205               0.873915
#  XGBRegressor                            0.871698               0.863445
#  ExtraTreesRegressor                     0.891616               0.883716
#  LinearRegression                        0.881855               0.877694
#  KNeighborsRegressor                     0.876523               0.862124
#  SVR                                     0.889586               0.878495
#  MLPRegressor                            0.858753               0.847424
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.151706  0.296114   0.389494  0.756534  0.870355
#  DecisionTreeRegressor      0.159394  0.306940   0.399242  0.744196  0.863375
#  RandomForestRegressor      0.141390  0.285255   0.376019  0.773089  0.879632
#  GradientBoostingRegressor  0.149336  0.292368   0.386441  0.760337  0.872571
#  AdaBoostRegressor          0.161811  0.311955   0.402258  0.740316  0.860515
#  XGBRegressor               0.147365  0.295082   0.383882  0.763501  0.873850
#  ExtraTreesRegressor        0.145831  0.287005   0.381878  0.765963  0.875328
#  LinearRegression           0.152248  0.296053   0.390189  0.755665  0.869382
#  KNeighborsRegressor        0.155050  0.299612   0.393764  0.751167  0.866786
#  SVR                        0.156459  0.294118   0.395550  0.748905  0.866890
#  MLPRegressor               0.171177  0.323801   0.413735  0.725286  0.855858
#
#                             Test SCC
#  LGBMRegressor              0.846365
#  DecisionTreeRegressor      0.837910
#  RandomForestRegressor      0.850764
#  GradientBoostingRegressor  0.847942
#  AdaBoostRegressor          0.847309
#  XGBRegressor               0.841615
#  ExtraTreesRegressor        0.843742
#  LinearRegression           0.841228
#  KNeighborsRegressor        0.839282
#  SVR                        0.836634
#  MLPRegressor               0.821503  ,
#  'Atomic':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.139154               0.280758
#  DecisionTreeRegressor                   0.255063               0.381988
#  RandomForestRegressor                   0.129963               0.272409
#  GradientBoostingRegressor               0.139274               0.282019
#  AdaBoostRegressor                       0.145596               0.294454
#  XGBRegressor                            0.142406               0.286842
#  ExtraTreesRegressor                     0.127802               0.270198
#  LinearRegression                        0.138872               0.286391
#  KNeighborsRegressor                     0.142015               0.284542
#  SVR                                     0.135945               0.279880
#  MLPRegressor                            0.179748               0.333173
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.373033              0.782872
#  DecisionTreeRegressor                    0.505038              0.602013
#  RandomForestRegressor                    0.360504              0.797212
#  GradientBoostingRegressor                0.373195              0.782683
#  AdaBoostRegressor                        0.381570              0.772819
#  XGBRegressor                             0.377367              0.777797
#  ExtraTreesRegressor                      0.357494              0.800585
#  LinearRegression                         0.372655              0.783311
#  KNeighborsRegressor                      0.376849              0.778407
#  SVR                                      0.368707              0.787879
#  MLPRegressor                             0.423967              0.719530
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.884968               0.878914
#  DecisionTreeRegressor                   0.799979               0.791446
#  RandomForestRegressor                   0.892877               0.884524
#  GradientBoostingRegressor               0.884899               0.876031
#  AdaBoostRegressor                       0.879212               0.870184
#  XGBRegressor                            0.882136               0.872726
#  ExtraTreesRegressor                     0.894828               0.886538
#  LinearRegression                        0.885155               0.878365
#  KNeighborsRegressor                     0.882631               0.869313
#  SVR                                     0.887662               0.875478
#  MLPRegressor                            0.849599               0.842440
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.148696  0.291675   0.385611  0.761365  0.873037
#  DecisionTreeRegressor      0.147022  0.295113   0.383434  0.764052  0.874326
#  RandomForestRegressor      0.136739  0.278761   0.369783  0.780554  0.883653
#  GradientBoostingRegressor  0.145464  0.287624   0.381397  0.766552  0.875619
#  AdaBoostRegressor          0.159348  0.303055   0.399184  0.744270  0.862749
#  XGBRegressor               0.144831  0.291363   0.380567  0.767567  0.876301
#  ExtraTreesRegressor        0.139967  0.279921   0.374121  0.775374  0.880644
#  LinearRegression           0.147385  0.287402   0.383907  0.763469  0.873814
#  KNeighborsRegressor        0.157772  0.303954   0.397205  0.746799  0.864631
#  SVR                        0.146184  0.284756   0.382340  0.765396  0.875942
#  MLPRegressor               0.178083  0.330937   0.421998  0.714204  0.847165
#
#                             Test SCC
#  LGBMRegressor              0.848474
#  DecisionTreeRegressor      0.848316
#  RandomForestRegressor      0.855402
#  GradientBoostingRegressor  0.850887
#  AdaBoostRegressor          0.844414
#  XGBRegressor               0.844970
#  ExtraTreesRegressor        0.852898
#  LinearRegression           0.845384
#  KNeighborsRegressor        0.832876
#  SVR                        0.853355
#  MLPRegressor               0.808085  ,
#  'Embeddings':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.169315               0.304658
#  DecisionTreeRegressor                   0.313774               0.417364
#  RandomForestRegressor                   0.158509               0.293612
#  GradientBoostingRegressor               0.163287               0.297670
#  AdaBoostRegressor                       0.175461               0.317814
#  XGBRegressor                            0.182983               0.316342
#  ExtraTreesRegressor                     0.153509               0.290732
#  LinearRegression                        0.165942               0.308003
#  KNeighborsRegressor                     0.168843               0.307897
#  SVR                                     0.165358               0.303216
#  MLPRegressor                            0.209783               0.366016
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.411479              0.735810
#  DecisionTreeRegressor                    0.560155              0.510404
#  RandomForestRegressor                    0.398132              0.752671
#  GradientBoostingRegressor                0.404088              0.745215
#  AdaBoostRegressor                        0.418881              0.726219
#  XGBRegressor                             0.427765              0.714482
#  ExtraTreesRegressor                      0.391802              0.760473
#  LinearRegression                         0.407360              0.741072
#  KNeighborsRegressor                      0.410905              0.736546
#  SVR                                      0.406643              0.741983
#  MLPRegressor                             0.458020              0.672666
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.858716               0.844781
#  DecisionTreeRegressor                   0.763434               0.753852
#  RandomForestRegressor                   0.867649               0.855100
#  GradientBoostingRegressor               0.863817               0.850578
#  AdaBoostRegressor                       0.853928               0.839729
#  XGBRegressor                            0.847490               0.834242
#  ExtraTreesRegressor                     0.872055               0.857443
#  LinearRegression                        0.861039               0.856363
#  KNeighborsRegressor                     0.859048               0.845155
#  SVR                                     0.861809               0.850662
#  MLPRegressor                            0.822415               0.813371
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.139066  0.281027   0.372915  0.776820  0.881548
#  DecisionTreeRegressor      0.154548  0.288984   0.393126  0.751973  0.868180
#  RandomForestRegressor      0.137063  0.280380   0.370220  0.780034  0.883280
#  GradientBoostingRegressor  0.139441  0.280856   0.373419  0.776217  0.881456
#  AdaBoostRegressor          0.147207  0.298262   0.383676  0.763754  0.876225
#  XGBRegressor               0.148765  0.288820   0.385700  0.761255  0.873406
#  ExtraTreesRegressor        0.135408  0.280568   0.367979  0.782689  0.884758
#  LinearRegression           0.131171  0.278050   0.362176  0.789489  0.888597
#  KNeighborsRegressor        0.148639  0.298462   0.385538  0.761455  0.873090
#  SVR                        0.143308  0.282652   0.378560  0.770012  0.879307
#  MLPRegressor               0.183589  0.341553   0.428472  0.705367  0.844223
#
#                             Test SCC
#  LGBMRegressor              0.867309
#  DecisionTreeRegressor      0.854666
#  RandomForestRegressor      0.864745
#  GradientBoostingRegressor  0.858083
#  AdaBoostRegressor          0.856506
#  XGBRegressor               0.855161
#  ExtraTreesRegressor        0.867865
#  LinearRegression           0.872522
#  KNeighborsRegressor        0.857593
#  SVR                        0.860057
#  MLPRegressor               0.807767  ,
#  'Fingerprints':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.141564               0.281569
#  DecisionTreeRegressor                   0.271756               0.391882
#  RandomForestRegressor                   0.135262               0.278107
#  GradientBoostingRegressor               0.138635               0.283505
#  AdaBoostRegressor                       0.148034               0.296178
#  XGBRegressor                            0.154649               0.298804
#  ExtraTreesRegressor                     0.129795               0.272502
#  LinearRegression                        0.138927               0.287939
#  KNeighborsRegressor                     0.142484               0.288525
#  SVR                                     0.136864               0.279978
#  MLPRegressor                            0.175624               0.332248
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.376250              0.779111
#  DecisionTreeRegressor                    0.521303              0.575965
#  RandomForestRegressor                    0.367780              0.788944
#  GradientBoostingRegressor                0.372338              0.783680
#  AdaBoostRegressor                        0.384752              0.769015
#  XGBRegressor                             0.393255              0.758693
#  ExtraTreesRegressor                      0.360270              0.797475
#  LinearRegression                         0.372730              0.783225
#  KNeighborsRegressor                      0.377471              0.777674
#  SVR                                      0.369951              0.786444
#  MLPRegressor                             0.419076              0.725964
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.882962               0.874687
#  DecisionTreeRegressor                   0.785439               0.779461
#  RandomForestRegressor                   0.888240               0.879825
#  GradientBoostingRegressor               0.885349               0.876590
#  AdaBoostRegressor                       0.876977               0.866742
#  XGBRegressor                            0.872116               0.864811
#  ExtraTreesRegressor                     0.893022               0.884719
#  LinearRegression                        0.885118               0.877757
#  KNeighborsRegressor                     0.882579               0.871396
#  SVR                                     0.886876               0.875307
#  MLPRegressor                            0.852921               0.842190
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.155754  0.297741   0.394656  0.750038  0.866693
#  DecisionTreeRegressor      0.153920  0.296005   0.392327  0.752981  0.868232
#  RandomForestRegressor      0.145350  0.284545   0.381248  0.766735  0.875636
#  GradientBoostingRegressor  0.149872  0.291511   0.387133  0.759477  0.871560
#  AdaBoostRegressor          0.163703  0.306937   0.404602  0.737281  0.859079
#  XGBRegressor               0.148440  0.293542   0.385279  0.761775  0.873225
#  ExtraTreesRegressor        0.147544  0.287039   0.384114  0.763214  0.873643
#  LinearRegression           0.151823  0.293240   0.389645  0.756346  0.869748
#  KNeighborsRegressor        0.166114  0.305432   0.407571  0.733411  0.857365
#  SVR                        0.147660  0.280860   0.384266  0.763027  0.874616
#  MLPRegressor               0.201966  0.349263   0.449406  0.675874  0.823730
#
#                             Test SCC
#  LGBMRegressor              0.842489
#  DecisionTreeRegressor      0.842570
#  RandomForestRegressor      0.846240
#  GradientBoostingRegressor  0.841337
#  AdaBoostRegressor          0.835785
#  XGBRegressor               0.840391
#  ExtraTreesRegressor        0.839236
#  LinearRegression           0.841075
#  KNeighborsRegressor        0.826280
#  SVR                        0.846440
#  MLPRegressor               0.782279  }

# %%
ablation_results.items()
# Out:
# dict_items([('Descriptor',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.139787               0.282037
# DecisionTreeRegressor                   0.273349               0.402000
# RandomForestRegressor                   0.133021               0.274761
# GradientBoostingRegressor               0.135888               0.280679
# AdaBoostRegressor                       0.144500               0.296127
# XGBRegressor                            0.154141               0.299476
# ExtraTreesRegressor                     0.131427               0.272303
# LinearRegression                        0.142635               0.290935
# KNeighborsRegressor                     0.148939               0.293499
# SVR                                     0.133759               0.278530
# MLPRegressor                            0.173988               0.323234
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.373881              0.781883
# DecisionTreeRegressor                    0.522828              0.573480
# RandomForestRegressor                    0.364720              0.792441
# GradientBoostingRegressor                0.368631              0.787966
# AdaBoostRegressor                        0.380132              0.774529
# XGBRegressor                             0.392608              0.759486
# ExtraTreesRegressor                      0.362528              0.794929
# LinearRegression                         0.377670              0.777440
# KNeighborsRegressor                      0.385927              0.767602
# SVR                                      0.365731              0.791289
# MLPRegressor                             0.417119              0.728518
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.884445               0.873364
# DecisionTreeRegressor                   0.783268               0.775736
# RandomForestRegressor                   0.890196               0.880727
# GradientBoostingRegressor               0.887826               0.876628
# AdaBoostRegressor                       0.880205               0.873915
# XGBRegressor                            0.871698               0.863445
# ExtraTreesRegressor                     0.891616               0.883716
# LinearRegression                        0.881855               0.877694
# KNeighborsRegressor                     0.876523               0.862124
# SVR                                     0.889586               0.878495
# MLPRegressor                            0.858753               0.847424
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.151706  0.296114   0.389494  0.756534  0.870355
# DecisionTreeRegressor      0.159394  0.306940   0.399242  0.744196  0.863375
# RandomForestRegressor      0.141390  0.285255   0.376019  0.773089  0.879632
# GradientBoostingRegressor  0.149336  0.292368   0.386441  0.760337  0.872571
# AdaBoostRegressor          0.161811  0.311955   0.402258  0.740316  0.860515
# XGBRegressor               0.147365  0.295082   0.383882  0.763501  0.873850
# ExtraTreesRegressor        0.145831  0.287005   0.381878  0.765963  0.875328
# LinearRegression           0.152248  0.296053   0.390189  0.755665  0.869382
# KNeighborsRegressor        0.155050  0.299612   0.393764  0.751167  0.866786
# SVR                        0.156459  0.294118   0.395550  0.748905  0.866890
# MLPRegressor               0.171177  0.323801   0.413735  0.725286  0.855858
#
#                            Test SCC
# LGBMRegressor              0.846365
# DecisionTreeRegressor      0.837910
# RandomForestRegressor      0.850764
# GradientBoostingRegressor  0.847942
# AdaBoostRegressor          0.847309
# XGBRegressor               0.841615
# ExtraTreesRegressor        0.843742
# LinearRegression           0.841228
# KNeighborsRegressor        0.839282
# SVR                        0.836634
# MLPRegressor               0.821503  ), ('Atomic',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.139154               0.280758
# DecisionTreeRegressor                   0.255063               0.381988
# RandomForestRegressor                   0.129963               0.272409
# GradientBoostingRegressor               0.139274               0.282019
# AdaBoostRegressor                       0.145596               0.294454
# XGBRegressor                            0.142406               0.286842
# ExtraTreesRegressor                     0.127802               0.270198
# LinearRegression                        0.138872               0.286391
# KNeighborsRegressor                     0.142015               0.284542
# SVR                                     0.135945               0.279880
# MLPRegressor                            0.179748               0.333173
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.373033              0.782872
# DecisionTreeRegressor                    0.505038              0.602013
# RandomForestRegressor                    0.360504              0.797212
# GradientBoostingRegressor                0.373195              0.782683
# AdaBoostRegressor                        0.381570              0.772819
# XGBRegressor                             0.377367              0.777797
# ExtraTreesRegressor                      0.357494              0.800585
# LinearRegression                         0.372655              0.783311
# KNeighborsRegressor                      0.376849              0.778407
# SVR                                      0.368707              0.787879
# MLPRegressor                             0.423967              0.719530
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.884968               0.878914
# DecisionTreeRegressor                   0.799979               0.791446
# RandomForestRegressor                   0.892877               0.884524
# GradientBoostingRegressor               0.884899               0.876031
# AdaBoostRegressor                       0.879212               0.870184
# XGBRegressor                            0.882136               0.872726
# ExtraTreesRegressor                     0.894828               0.886538
# LinearRegression                        0.885155               0.878365
# KNeighborsRegressor                     0.882631               0.869313
# SVR                                     0.887662               0.875478
# MLPRegressor                            0.849599               0.842440
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.148696  0.291675   0.385611  0.761365  0.873037
# DecisionTreeRegressor      0.147022  0.295113   0.383434  0.764052  0.874326
# RandomForestRegressor      0.136739  0.278761   0.369783  0.780554  0.883653
# GradientBoostingRegressor  0.145464  0.287624   0.381397  0.766552  0.875619
# AdaBoostRegressor          0.159348  0.303055   0.399184  0.744270  0.862749
# XGBRegressor               0.144831  0.291363   0.380567  0.767567  0.876301
# ExtraTreesRegressor        0.139967  0.279921   0.374121  0.775374  0.880644
# LinearRegression           0.147385  0.287402   0.383907  0.763469  0.873814
# KNeighborsRegressor        0.157772  0.303954   0.397205  0.746799  0.864631
# SVR                        0.146184  0.284756   0.382340  0.765396  0.875942
# MLPRegressor               0.178083  0.330937   0.421998  0.714204  0.847165
#
#                            Test SCC
# LGBMRegressor              0.848474
# DecisionTreeRegressor      0.848316
# RandomForestRegressor      0.855402
# GradientBoostingRegressor  0.850887
# AdaBoostRegressor          0.844414
# XGBRegressor               0.844970
# ExtraTreesRegressor        0.852898
# LinearRegression           0.845384
# KNeighborsRegressor        0.832876
# SVR                        0.853355
# MLPRegressor               0.808085  ), ('Embeddings',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.169315               0.304658
# DecisionTreeRegressor                   0.313774               0.417364
# RandomForestRegressor                   0.158509               0.293612
# GradientBoostingRegressor               0.163287               0.297670
# AdaBoostRegressor                       0.175461               0.317814
# XGBRegressor                            0.182983               0.316342
# ExtraTreesRegressor                     0.153509               0.290732
# LinearRegression                        0.165942               0.308003
# KNeighborsRegressor                     0.168843               0.307897
# SVR                                     0.165358               0.303216
# MLPRegressor                            0.209783               0.366016
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.411479              0.735810
# DecisionTreeRegressor                    0.560155              0.510404
# RandomForestRegressor                    0.398132              0.752671
# GradientBoostingRegressor                0.404088              0.745215
# AdaBoostRegressor                        0.418881              0.726219
# XGBRegressor                             0.427765              0.714482
# ExtraTreesRegressor                      0.391802              0.760473
# LinearRegression                         0.407360              0.741072
# KNeighborsRegressor                      0.410905              0.736546
# SVR                                      0.406643              0.741983
# MLPRegressor                             0.458020              0.672666
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.858716               0.844781
# DecisionTreeRegressor                   0.763434               0.753852
# RandomForestRegressor                   0.867649               0.855100
# GradientBoostingRegressor               0.863817               0.850578
# AdaBoostRegressor                       0.853928               0.839729
# XGBRegressor                            0.847490               0.834242
# ExtraTreesRegressor                     0.872055               0.857443
# LinearRegression                        0.861039               0.856363
# KNeighborsRegressor                     0.859048               0.845155
# SVR                                     0.861809               0.850662
# MLPRegressor                            0.822415               0.813371
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.139066  0.281027   0.372915  0.776820  0.881548
# DecisionTreeRegressor      0.154548  0.288984   0.393126  0.751973  0.868180
# RandomForestRegressor      0.137063  0.280380   0.370220  0.780034  0.883280
# GradientBoostingRegressor  0.139441  0.280856   0.373419  0.776217  0.881456
# AdaBoostRegressor          0.147207  0.298262   0.383676  0.763754  0.876225
# XGBRegressor               0.148765  0.288820   0.385700  0.761255  0.873406
# ExtraTreesRegressor        0.135408  0.280568   0.367979  0.782689  0.884758
# LinearRegression           0.131171  0.278050   0.362176  0.789489  0.888597
# KNeighborsRegressor        0.148639  0.298462   0.385538  0.761455  0.873090
# SVR                        0.143308  0.282652   0.378560  0.770012  0.879307
# MLPRegressor               0.183589  0.341553   0.428472  0.705367  0.844223
#
#                            Test SCC
# LGBMRegressor              0.867309
# DecisionTreeRegressor      0.854666
# RandomForestRegressor      0.864745
# GradientBoostingRegressor  0.858083
# AdaBoostRegressor          0.856506
# XGBRegressor               0.855161
# ExtraTreesRegressor        0.867865
# LinearRegression           0.872522
# KNeighborsRegressor        0.857593
# SVR                        0.860057
# MLPRegressor               0.807767  ), ('Fingerprints',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.141564               0.281569
# DecisionTreeRegressor                   0.271756               0.391882
# RandomForestRegressor                   0.135262               0.278107
# GradientBoostingRegressor               0.138635               0.283505
# AdaBoostRegressor                       0.148034               0.296178
# XGBRegressor                            0.154649               0.298804
# ExtraTreesRegressor                     0.129795               0.272502
# LinearRegression                        0.138927               0.287939
# KNeighborsRegressor                     0.142484               0.288525
# SVR                                     0.136864               0.279978
# MLPRegressor                            0.175624               0.332248
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.376250              0.779111
# DecisionTreeRegressor                    0.521303              0.575965
# RandomForestRegressor                    0.367780              0.788944
# GradientBoostingRegressor                0.372338              0.783680
# AdaBoostRegressor                        0.384752              0.769015
# XGBRegressor                             0.393255              0.758693
# ExtraTreesRegressor                      0.360270              0.797475
# LinearRegression                         0.372730              0.783225
# KNeighborsRegressor                      0.377471              0.777674
# SVR                                      0.369951              0.786444
# MLPRegressor                             0.419076              0.725964
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.882962               0.874687
# DecisionTreeRegressor                   0.785439               0.779461
# RandomForestRegressor                   0.888240               0.879825
# GradientBoostingRegressor               0.885349               0.876590
# AdaBoostRegressor                       0.876977               0.866742
# XGBRegressor                            0.872116               0.864811
# ExtraTreesRegressor                     0.893022               0.884719
# LinearRegression                        0.885118               0.877757
# KNeighborsRegressor                     0.882579               0.871396
# SVR                                     0.886876               0.875307
# MLPRegressor                            0.852921               0.842190
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.155754  0.297741   0.394656  0.750038  0.866693
# DecisionTreeRegressor      0.153920  0.296005   0.392327  0.752981  0.868232
# RandomForestRegressor      0.145350  0.284545   0.381248  0.766735  0.875636
# GradientBoostingRegressor  0.149872  0.291511   0.387133  0.759477  0.871560
# AdaBoostRegressor          0.163703  0.306937   0.404602  0.737281  0.859079
# XGBRegressor               0.148440  0.293542   0.385279  0.761775  0.873225
# ExtraTreesRegressor        0.147544  0.287039   0.384114  0.763214  0.873643
# LinearRegression           0.151823  0.293240   0.389645  0.756346  0.869748
# KNeighborsRegressor        0.166114  0.305432   0.407571  0.733411  0.857365
# SVR                        0.147660  0.280860   0.384266  0.763027  0.874616
# MLPRegressor               0.201966  0.349263   0.449406  0.675874  0.823730
#
#                            Test SCC
# LGBMRegressor              0.842489
# DecisionTreeRegressor      0.842570
# RandomForestRegressor      0.846240
# GradientBoostingRegressor  0.841337
# AdaBoostRegressor          0.835785
# XGBRegressor               0.840391
# ExtraTreesRegressor        0.839236
# LinearRegression           0.841075
# KNeighborsRegressor        0.826280
# SVR                        0.846440
# MLPRegressor               0.782279  )])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import os
import pandas as pd

plots_dir = '/home/users/akshay/PCPpred/Caco2/results/Ablation/plots'
os.makedirs(plots_dir, exist_ok=True)
actual_values = {
    "Test MSE": 0.1355,
    "Test MAE": 0.2768,
    "Test RMSE": 0.3681,
    "Test R2": 0.7826,
    "Test PCC": 0.8848,
    "Test SCC": 0.8571
}

metrics = ["Test MSE", "Test MAE", "Test RMSE", "Test R2", "Test PCC", "Test SCC"]
y_label = {"Test MSE":"MSE score", "Test MAE":"MAE score", "Test RMSE":"RMSE score", "Test R2":"R2 score", "Test PCC":"PCC score", "Test SCC":"SCC score"}
num_bars = len(ablation_results)
colors = cm.get_cmap('tab10', num_bars).colors

for metric in metrics:
    metric_data = {label: df.loc["RandomForestRegressor", metric] for label, df in ablation_results.items()}
    metric_series = pd.Series(metric_data)

    fig, ax = plt.subplots(figsize=(5, 7))
    bars = ax.bar(metric_series.index, metric_series.values, color=colors, edgecolor='black', linewidth=1.2)

    y_max = metric_series.max()
    if metric == 'Test R2':
        ax.set_ylim(0.72, y_max + 0.01)
    if metric == 'Test MSE':
        ax.set_ylim(0.12, y_max + 0.005)
    if metric == 'Test RMSE':
        ax.set_ylim(0.34, y_max + 0.005)
    if metric == 'Test PCC':
        ax.set_ylim(0.83, y_max + 0.01)
    if metric == 'Test SCC':
        ax.set_ylim(0.82, y_max + 0.005)
    if metric == 'Test MAE':
        ax.set_ylim(0.24, y_max + 0.01)

    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

    actual_value = actual_values[metric]
    ax.axhline(y=actual_value, color='red', linestyle='--', linewidth=1.5,
               label=f'Actual {metric.split()[-1]}: {actual_value:.4f}')

    ax.legend(loc='upper right', fontsize=9)

    ax.set_title(f'Caco-2 {metric}', fontsize=14)
    ax.set_xlabel('Ablation Study', fontsize=10)
    ax.set_ylabel(y_label[metric], fontsize=10)
    ax.set_xticks(range(len(metric_series)))
    ax.set_xticklabels(metric_series.index, rotation=55, ha='right')
    ax.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()

    save_path = os.path.join(plots_dir, f"{metric.replace(' ', '_')}.png")
    plt.savefig(save_path, dpi=300)
    print(f"Saved plot for {metric} to {save_path}")
    plt.show()
# Out:
# /tmp/ipykernel_3167615/4078801843.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap('tab10', num_bars).colors
# Saved plot for Test MSE to /home/users/akshay/PCPpred/Caco2/results/Ablation/plots/Test_MSE.png
# Saved plot for Test MAE to /home/users/akshay/PCPpred/Caco2/results/Ablation/plots/Test_MAE.png
# Saved plot for Test RMSE to /home/users/akshay/PCPpred/Caco2/results/Ablation/plots/Test_RMSE.png
# Saved plot for Test R2 to /home/users/akshay/PCPpred/Caco2/results/Ablation/plots/Test_R2.png
# Saved plot for Test PCC to /home/users/akshay/PCPpred/Caco2/results/Ablation/plots/Test_PCC.png
# Saved plot for Test SCC to /home/users/akshay/PCPpred/Caco2/results/Ablation/plots/Test_SCC.png
