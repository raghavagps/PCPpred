# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.cm as cm
import numpy as np

dataframes = ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)',
              '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']

ablation_results = {}

for ablation_idx in range(len(dataframes)):
    print(f"========== Ablation: Excluding feature at index {ablation_idx} ==========")
    excluded_dataframe = dataframes[ablation_idx]
    print('Excluded dataframe:', excluded_dataframe)

    ablated_dataframes = [pair for i, pair in enumerate(dataframes) if i != ablation_idx]
    print('Ablated index', ablation_idx, '----->', 'Ablated_dataframes', ablated_dataframes)
# Out:
# ========== Ablation: Excluding feature at index 0 ==========
# Excluded dataframe: (df_desc_train, df_desc_test)
# Ablated index 0 -----> Ablated_dataframes ['(df_fp_train, df_fp_test)', '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 1 ==========
# Excluded dataframe: (df_fp_train, df_fp_test)
# Ablated index 1 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_emb_train, df_emb_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 2 ==========
# Excluded dataframe: (df_emb_train, df_emb_test)
# Ablated index 2 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)', '(df_atomic_train, df_atomic_test)']
# ========== Ablation: Excluding feature at index 3 ==========
# Excluded dataframe: (df_atomic_train, df_atomic_test)
# Ablated index 3 -----> Ablated_dataframes ['(df_desc_train, df_desc_test)', '(df_fp_train, df_fp_test)', '(df_emb_train, df_emb_test)']

# %%
ablation_result_dir = '/home/users/akshay/PCPpred/MDCK/results/Ablation/'

ablation_results = {}
for filename in os.listdir(ablation_result_dir):
    if filename.endswith('.csv'):
        ablation_label = filename.replace('.csv', '').replace("Ablation_", "")
        print(ablation_label)
        file_path = os.path.join(ablation_result_dir, filename)
    
        ablation_results[ablation_label] = pd.read_csv(file_path, index_col=0)


ablation_results
# Out:
# Descriptor
# Atomic
# Embeddings
# Fingerprints
# {'Descriptor':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.503358               0.567099
#  DecisionTreeRegressor                   0.577553               0.568427
#  RandomForestRegressor                   0.466624               0.510971
#  GradientBoostingRegressor               0.466880               0.498177
#  AdaBoostRegressor                       0.471033               0.518688
#  XGBRegressor                            0.628357               0.535791
#  ExtraTreesRegressor                     0.508204               0.527568
#  LinearRegression                        2.378658               1.284206
#  KNeighborsRegressor                     0.518403               0.566811
#  SVR                                     0.491298               0.566631
#  MLPRegressor                            0.873538               0.794884
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.709477              0.043348
#  DecisionTreeRegressor                    0.759969             -0.097664
#  RandomForestRegressor                    0.683099              0.113162
#  GradientBoostingRegressor                0.683286              0.112676
#  AdaBoostRegressor                        0.686318              0.104782
#  XGBRegressor                             0.792690             -0.194219
#  ExtraTreesRegressor                      0.712884              0.034138
#  LinearRegression                         1.542290             -3.520739
#  KNeighborsRegressor                      0.720002              0.014753
#  SVR                                      0.700927              0.066267
#  MLPRegressor                             0.934633             -0.660195
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.277158               0.292044
#  DecisionTreeRegressor                   0.439369               0.432694
#  RandomForestRegressor                   0.392832               0.464689
#  GradientBoostingRegressor               0.423455               0.471296
#  AdaBoostRegressor                       0.407138               0.448983
#  XGBRegressor                            0.334388               0.444311
#  ExtraTreesRegressor                     0.310918               0.421967
#  LinearRegression                       -0.048723              -0.062426
#  KNeighborsRegressor                     0.287161               0.286775
#  SVR                                     0.289401               0.268821
#  MLPRegressor                            0.354060               0.389745
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.613003  0.655185   0.782945  0.142809  0.394748
#  DecisionTreeRegressor      0.592180  0.575125   0.769533  0.171927  0.440232
#  RandomForestRegressor      0.530418  0.573422   0.728298  0.258291  0.512479
#  GradientBoostingRegressor  0.570246  0.603582   0.755146  0.202598  0.454259
#  AdaBoostRegressor          0.540633  0.571399   0.735277  0.244008  0.508420
#  XGBRegressor               0.604119  0.634384   0.777251  0.155233  0.402541
#  ExtraTreesRegressor        0.513400  0.569686   0.716519  0.282089  0.542318
#  LinearRegression           1.299883  0.989309   1.140124 -0.817687 -0.058674
#  KNeighborsRegressor        0.501576  0.585611   0.708221  0.298623  0.568320
#  SVR                        0.497181  0.557132   0.705110  0.304769  0.606464
#  MLPRegressor               0.937917  0.831956   0.968461 -0.311533  0.624565
#
#                             Test SCC
#  LGBMRegressor              0.285912
#  DecisionTreeRegressor      0.333335
#  RandomForestRegressor      0.355373
#  GradientBoostingRegressor  0.311296
#  AdaBoostRegressor          0.468321
#  XGBRegressor               0.261709
#  ExtraTreesRegressor        0.371902
#  LinearRegression          -0.179064
#  KNeighborsRegressor        0.451792
#  SVR                        0.385676
#  MLPRegressor               0.512399  ,
#  'Atomic':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.425195               0.533250
#  DecisionTreeRegressor                   0.481531               0.532472
#  RandomForestRegressor                   0.306747               0.421264
#  GradientBoostingRegressor               0.292272               0.429059
#  AdaBoostRegressor                       0.301810               0.427568
#  XGBRegressor                            0.265959               0.409422
#  ExtraTreesRegressor                     0.355315               0.421548
#  LinearRegression                        2.472427               1.283968
#  KNeighborsRegressor                     0.522755               0.542199
#  SVR                                     0.437850               0.510385
#  MLPRegressor                            0.704546               0.714361
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.652070              0.191899
#  DecisionTreeRegressor                    0.693924              0.084830
#  RandomForestRegressor                    0.553847              0.417015
#  GradientBoostingRegressor                0.540622              0.444524
#  AdaBoostRegressor                        0.549372              0.426398
#  XGBRegressor                             0.515712              0.494535
#  ExtraTreesRegressor                      0.596083              0.324708
#  LinearRegression                         1.572395             -3.698950
#  KNeighborsRegressor                      0.723018              0.006482
#  SVR                                      0.661702              0.167848
#  MLPRegressor                             0.839372             -0.339018
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.442862               0.420284
#  DecisionTreeRegressor                   0.592295               0.652298
#  RandomForestRegressor                   0.653577               0.702283
#  GradientBoostingRegressor               0.676216               0.694673
#  AdaBoostRegressor                       0.655282               0.679618
#  XGBRegressor                            0.713962               0.745406
#  ExtraTreesRegressor                     0.572566               0.658883
#  LinearRegression                        0.119668               0.098756
#  KNeighborsRegressor                     0.284024               0.361470
#  SVR                                     0.424388               0.439617
#  MLPRegressor                            0.422381               0.443283
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.532925  0.593038   0.730017  0.254786  0.539189
#  DecisionTreeRegressor      0.409409  0.486356   0.639851  0.427504  0.661810
#  RandomForestRegressor      0.322031  0.424368   0.567478  0.549689  0.775800
#  GradientBoostingRegressor  0.315780  0.414109   0.561943  0.558429  0.794206
#  AdaBoostRegressor          0.330740  0.415523   0.575100  0.537511  0.771789
#  XGBRegressor               0.266275  0.400423   0.516018  0.627655  0.867628
#  ExtraTreesRegressor        0.290831  0.410723   0.539287  0.593318  0.829232
#  LinearRegression           0.640069  0.593219   0.800043  0.104961  0.453198
#  KNeighborsRegressor        0.488220  0.533166   0.698728  0.317299  0.579964
#  SVR                        0.375309  0.437110   0.612625  0.475188  0.721271
#  MLPRegressor               0.916950  0.826093   0.957575 -0.282214  0.459857
#
#                             Test SCC
#  LGBMRegressor              0.508287
#  DecisionTreeRegressor      0.652895
#  RandomForestRegressor      0.694218
#  GradientBoostingRegressor  0.710746
#  AdaBoostRegressor          0.705237
#  XGBRegressor               0.763088
#  ExtraTreesRegressor        0.688708
#  LinearRegression           0.385676
#  KNeighborsRegressor        0.487605
#  SVR                        0.672179
#  MLPRegressor               0.344354  ,
#  'Embeddings':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.410452               0.520207
#  DecisionTreeRegressor                   0.644068               0.612025
#  RandomForestRegressor                   0.295846               0.417605
#  GradientBoostingRegressor               0.376594               0.497852
#  AdaBoostRegressor                       0.284824               0.409992
#  XGBRegressor                            0.354755               0.442841
#  ExtraTreesRegressor                     0.327558               0.424536
#  LinearRegression                        1.747022               1.023575
#  KNeighborsRegressor                     0.545768               0.545768
#  SVR                                     0.462973               0.538896
#  MLPRegressor                            0.669041               0.684426
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.640665              0.219919
#  DecisionTreeRegressor                    0.802538             -0.224077
#  RandomForestRegressor                    0.543917              0.437732
#  GradientBoostingRegressor                0.613673              0.284267
#  AdaBoostRegressor                        0.533689              0.458680
#  XGBRegressor                             0.595613              0.325773
#  ExtraTreesRegressor                      0.572327              0.377462
#  LinearRegression                         1.321750             -2.320289
#  KNeighborsRegressor                      0.738761             -0.037255
#  SVR                                      0.680421              0.120100
#  MLPRegressor                             0.817949             -0.271540
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.472248               0.417877
#  DecisionTreeRegressor                   0.538232               0.557514
#  RandomForestRegressor                   0.668514               0.718394
#  GradientBoostingRegressor               0.603362               0.638192
#  AdaBoostRegressor                       0.680241               0.690534
#  XGBRegressor                            0.649499               0.691279
#  ExtraTreesRegressor                     0.615243               0.665716
#  LinearRegression                        0.203531               0.225147
#  KNeighborsRegressor                     0.240513               0.305995
#  SVR                                     0.376156               0.376938
#  MLPRegressor                            0.381941               0.448487
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.532775  0.591934   0.729914  0.254997  0.529031
#  DecisionTreeRegressor      0.270048  0.408745   0.519662  0.622379  0.799831
#  RandomForestRegressor      0.305478  0.400865   0.552701  0.572835  0.786781
#  GradientBoostingRegressor  0.283690  0.393016   0.532625  0.603304  0.811314
#  AdaBoostRegressor          0.295744  0.395263   0.543824  0.586447  0.822908
#  XGBRegressor               0.219190  0.347367   0.468177  0.693497  0.915576
#  ExtraTreesRegressor        0.282379  0.397701   0.531394  0.605136  0.824636
#  LinearRegression           0.916424  0.762297   0.957300 -0.281478  0.446887
#  KNeighborsRegressor        0.537109  0.598481   0.732877  0.248935  0.505772
#  SVR                        0.410105  0.472811   0.640394  0.426532  0.678524
#  MLPRegressor               1.009943  0.884901   1.004959 -0.412250  0.388850
#
#                             Test SCC
#  LGBMRegressor              0.609656
#  DecisionTreeRegressor      0.730030
#  RandomForestRegressor      0.655650
#  GradientBoostingRegressor  0.732785
#  AdaBoostRegressor          0.779617
#  XGBRegressor               0.903585
#  ExtraTreesRegressor        0.796146
#  LinearRegression           0.421489
#  KNeighborsRegressor        0.460057
#  SVR                        0.674934
#  MLPRegressor               0.256199  ,
#  'Fingerprints':                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
#  LGBMRegressor                           0.498840               0.574929
#  DecisionTreeRegressor                   0.454037               0.515434
#  RandomForestRegressor                   0.310232               0.429055
#  GradientBoostingRegressor               0.330833               0.469280
#  AdaBoostRegressor                       0.300629               0.410924
#  XGBRegressor                            0.409597               0.513515
#  ExtraTreesRegressor                     0.351062               0.422073
#  LinearRegression                        1.346440               0.921411
#  KNeighborsRegressor                     0.480626               0.550127
#  SVR                                     0.458571               0.546571
#  MLPRegressor                            0.750429               0.749271
#
#                             Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
#  LGBMRegressor                            0.706286              0.051933
#  DecisionTreeRegressor                    0.673822              0.137085
#  RandomForestRegressor                    0.556985              0.410391
#  GradientBoostingRegressor                0.575180              0.371239
#  AdaBoostRegressor                        0.548297              0.428641
#  XGBRegressor                             0.639998              0.221543
#  ExtraTreesRegressor                      0.592505              0.332793
#  LinearRegression                         1.160362             -1.558965
#  KNeighborsRegressor                      0.693272              0.086550
#  SVR                                      0.677178              0.128468
#  MLPRegressor                             0.866273             -0.426221
#
#                             Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
#  LGBMRegressor                           0.316680               0.298365
#  DecisionTreeRegressor                   0.586595               0.578950
#  RandomForestRegressor                   0.650621               0.686715
#  GradientBoostingRegressor               0.646906               0.652547
#  AdaBoostRegressor                       0.672120               0.701417
#  XGBRegressor                            0.587984               0.649280
#  ExtraTreesRegressor                     0.582350               0.635078
#  LinearRegression                        0.131250               0.141625
#  KNeighborsRegressor                     0.369006               0.438564
#  SVR                                     0.386355               0.371235
#  MLPRegressor                            0.430860               0.454959
#
#                             Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
#  LGBMRegressor              0.520286  0.591037   0.721309  0.272460  0.554981
#  DecisionTreeRegressor      0.433318  0.485460   0.658269  0.394071  0.634516
#  RandomForestRegressor      0.335104  0.418653   0.578882  0.531408  0.752178
#  GradientBoostingRegressor  0.342794  0.425769   0.585486  0.520656  0.742117
#  AdaBoostRegressor          0.341409  0.412172   0.584302  0.522593  0.743594
#  XGBRegressor               0.273350  0.409087   0.522829  0.617762  0.860025
#  ExtraTreesRegressor        0.290871  0.391398   0.539324  0.593262  0.846068
#  LinearRegression           0.803027  0.717383   0.896118 -0.122910  0.227078
#  KNeighborsRegressor        0.400716  0.481264   0.633021  0.439660  0.681463
#  SVR                        0.376078  0.461490   0.613252  0.474112  0.729364
#  MLPRegressor               1.090373  0.917331   1.044209 -0.524720  0.437491
#
#                             Test SCC
#  LGBMRegressor              0.490360
#  DecisionTreeRegressor      0.506889
#  RandomForestRegressor      0.647385
#  GradientBoostingRegressor  0.666669
#  AdaBoostRegressor          0.661160
#  XGBRegressor               0.685953
#  ExtraTreesRegressor        0.738295
#  LinearRegression           0.165290
#  KNeighborsRegressor        0.666669
#  SVR                        0.672179
#  MLPRegressor               0.366393  }

# %%
ablation_results.items()
# Out:
# dict_items([('Descriptor',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.503358               0.567099
# DecisionTreeRegressor                   0.577553               0.568427
# RandomForestRegressor                   0.466624               0.510971
# GradientBoostingRegressor               0.466880               0.498177
# AdaBoostRegressor                       0.471033               0.518688
# XGBRegressor                            0.628357               0.535791
# ExtraTreesRegressor                     0.508204               0.527568
# LinearRegression                        2.378658               1.284206
# KNeighborsRegressor                     0.518403               0.566811
# SVR                                     0.491298               0.566631
# MLPRegressor                            0.873538               0.794884
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.709477              0.043348
# DecisionTreeRegressor                    0.759969             -0.097664
# RandomForestRegressor                    0.683099              0.113162
# GradientBoostingRegressor                0.683286              0.112676
# AdaBoostRegressor                        0.686318              0.104782
# XGBRegressor                             0.792690             -0.194219
# ExtraTreesRegressor                      0.712884              0.034138
# LinearRegression                         1.542290             -3.520739
# KNeighborsRegressor                      0.720002              0.014753
# SVR                                      0.700927              0.066267
# MLPRegressor                             0.934633             -0.660195
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.277158               0.292044
# DecisionTreeRegressor                   0.439369               0.432694
# RandomForestRegressor                   0.392832               0.464689
# GradientBoostingRegressor               0.423455               0.471296
# AdaBoostRegressor                       0.407138               0.448983
# XGBRegressor                            0.334388               0.444311
# ExtraTreesRegressor                     0.310918               0.421967
# LinearRegression                       -0.048723              -0.062426
# KNeighborsRegressor                     0.287161               0.286775
# SVR                                     0.289401               0.268821
# MLPRegressor                            0.354060               0.389745
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.613003  0.655185   0.782945  0.142809  0.394748
# DecisionTreeRegressor      0.592180  0.575125   0.769533  0.171927  0.440232
# RandomForestRegressor      0.530418  0.573422   0.728298  0.258291  0.512479
# GradientBoostingRegressor  0.570246  0.603582   0.755146  0.202598  0.454259
# AdaBoostRegressor          0.540633  0.571399   0.735277  0.244008  0.508420
# XGBRegressor               0.604119  0.634384   0.777251  0.155233  0.402541
# ExtraTreesRegressor        0.513400  0.569686   0.716519  0.282089  0.542318
# LinearRegression           1.299883  0.989309   1.140124 -0.817687 -0.058674
# KNeighborsRegressor        0.501576  0.585611   0.708221  0.298623  0.568320
# SVR                        0.497181  0.557132   0.705110  0.304769  0.606464
# MLPRegressor               0.937917  0.831956   0.968461 -0.311533  0.624565
#
#                            Test SCC
# LGBMRegressor              0.285912
# DecisionTreeRegressor      0.333335
# RandomForestRegressor      0.355373
# GradientBoostingRegressor  0.311296
# AdaBoostRegressor          0.468321
# XGBRegressor               0.261709
# ExtraTreesRegressor        0.371902
# LinearRegression          -0.179064
# KNeighborsRegressor        0.451792
# SVR                        0.385676
# MLPRegressor               0.512399  ), ('Atomic',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.425195               0.533250
# DecisionTreeRegressor                   0.481531               0.532472
# RandomForestRegressor                   0.306747               0.421264
# GradientBoostingRegressor               0.292272               0.429059
# AdaBoostRegressor                       0.301810               0.427568
# XGBRegressor                            0.265959               0.409422
# ExtraTreesRegressor                     0.355315               0.421548
# LinearRegression                        2.472427               1.283968
# KNeighborsRegressor                     0.522755               0.542199
# SVR                                     0.437850               0.510385
# MLPRegressor                            0.704546               0.714361
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.652070              0.191899
# DecisionTreeRegressor                    0.693924              0.084830
# RandomForestRegressor                    0.553847              0.417015
# GradientBoostingRegressor                0.540622              0.444524
# AdaBoostRegressor                        0.549372              0.426398
# XGBRegressor                             0.515712              0.494535
# ExtraTreesRegressor                      0.596083              0.324708
# LinearRegression                         1.572395             -3.698950
# KNeighborsRegressor                      0.723018              0.006482
# SVR                                      0.661702              0.167848
# MLPRegressor                             0.839372             -0.339018
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.442862               0.420284
# DecisionTreeRegressor                   0.592295               0.652298
# RandomForestRegressor                   0.653577               0.702283
# GradientBoostingRegressor               0.676216               0.694673
# AdaBoostRegressor                       0.655282               0.679618
# XGBRegressor                            0.713962               0.745406
# ExtraTreesRegressor                     0.572566               0.658883
# LinearRegression                        0.119668               0.098756
# KNeighborsRegressor                     0.284024               0.361470
# SVR                                     0.424388               0.439617
# MLPRegressor                            0.422381               0.443283
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.532925  0.593038   0.730017  0.254786  0.539189
# DecisionTreeRegressor      0.409409  0.486356   0.639851  0.427504  0.661810
# RandomForestRegressor      0.322031  0.424368   0.567478  0.549689  0.775800
# GradientBoostingRegressor  0.315780  0.414109   0.561943  0.558429  0.794206
# AdaBoostRegressor          0.330740  0.415523   0.575100  0.537511  0.771789
# XGBRegressor               0.266275  0.400423   0.516018  0.627655  0.867628
# ExtraTreesRegressor        0.290831  0.410723   0.539287  0.593318  0.829232
# LinearRegression           0.640069  0.593219   0.800043  0.104961  0.453198
# KNeighborsRegressor        0.488220  0.533166   0.698728  0.317299  0.579964
# SVR                        0.375309  0.437110   0.612625  0.475188  0.721271
# MLPRegressor               0.916950  0.826093   0.957575 -0.282214  0.459857
#
#                            Test SCC
# LGBMRegressor              0.508287
# DecisionTreeRegressor      0.652895
# RandomForestRegressor      0.694218
# GradientBoostingRegressor  0.710746
# AdaBoostRegressor          0.705237
# XGBRegressor               0.763088
# ExtraTreesRegressor        0.688708
# LinearRegression           0.385676
# KNeighborsRegressor        0.487605
# SVR                        0.672179
# MLPRegressor               0.344354  ), ('Embeddings',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.410452               0.520207
# DecisionTreeRegressor                   0.644068               0.612025
# RandomForestRegressor                   0.295846               0.417605
# GradientBoostingRegressor               0.376594               0.497852
# AdaBoostRegressor                       0.284824               0.409992
# XGBRegressor                            0.354755               0.442841
# ExtraTreesRegressor                     0.327558               0.424536
# LinearRegression                        1.747022               1.023575
# KNeighborsRegressor                     0.545768               0.545768
# SVR                                     0.462973               0.538896
# MLPRegressor                            0.669041               0.684426
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.640665              0.219919
# DecisionTreeRegressor                    0.802538             -0.224077
# RandomForestRegressor                    0.543917              0.437732
# GradientBoostingRegressor                0.613673              0.284267
# AdaBoostRegressor                        0.533689              0.458680
# XGBRegressor                             0.595613              0.325773
# ExtraTreesRegressor                      0.572327              0.377462
# LinearRegression                         1.321750             -2.320289
# KNeighborsRegressor                      0.738761             -0.037255
# SVR                                      0.680421              0.120100
# MLPRegressor                             0.817949             -0.271540
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.472248               0.417877
# DecisionTreeRegressor                   0.538232               0.557514
# RandomForestRegressor                   0.668514               0.718394
# GradientBoostingRegressor               0.603362               0.638192
# AdaBoostRegressor                       0.680241               0.690534
# XGBRegressor                            0.649499               0.691279
# ExtraTreesRegressor                     0.615243               0.665716
# LinearRegression                        0.203531               0.225147
# KNeighborsRegressor                     0.240513               0.305995
# SVR                                     0.376156               0.376938
# MLPRegressor                            0.381941               0.448487
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.532775  0.591934   0.729914  0.254997  0.529031
# DecisionTreeRegressor      0.270048  0.408745   0.519662  0.622379  0.799831
# RandomForestRegressor      0.305478  0.400865   0.552701  0.572835  0.786781
# GradientBoostingRegressor  0.283690  0.393016   0.532625  0.603304  0.811314
# AdaBoostRegressor          0.295744  0.395263   0.543824  0.586447  0.822908
# XGBRegressor               0.219190  0.347367   0.468177  0.693497  0.915576
# ExtraTreesRegressor        0.282379  0.397701   0.531394  0.605136  0.824636
# LinearRegression           0.916424  0.762297   0.957300 -0.281478  0.446887
# KNeighborsRegressor        0.537109  0.598481   0.732877  0.248935  0.505772
# SVR                        0.410105  0.472811   0.640394  0.426532  0.678524
# MLPRegressor               1.009943  0.884901   1.004959 -0.412250  0.388850
#
#                            Test SCC
# LGBMRegressor              0.609656
# DecisionTreeRegressor      0.730030
# RandomForestRegressor      0.655650
# GradientBoostingRegressor  0.732785
# AdaBoostRegressor          0.779617
# XGBRegressor               0.903585
# ExtraTreesRegressor        0.796146
# LinearRegression           0.421489
# KNeighborsRegressor        0.460057
# SVR                        0.674934
# MLPRegressor               0.256199  ), ('Fingerprints',                            Train MSE (5 fold CV)  Train MAE (5 fold CV)  \
# LGBMRegressor                           0.498840               0.574929
# DecisionTreeRegressor                   0.454037               0.515434
# RandomForestRegressor                   0.310232               0.429055
# GradientBoostingRegressor               0.330833               0.469280
# AdaBoostRegressor                       0.300629               0.410924
# XGBRegressor                            0.409597               0.513515
# ExtraTreesRegressor                     0.351062               0.422073
# LinearRegression                        1.346440               0.921411
# KNeighborsRegressor                     0.480626               0.550127
# SVR                                     0.458571               0.546571
# MLPRegressor                            0.750429               0.749271
#
#                            Train RMSE (5 fold CV)  Train R2 (5 fold CV)  \
# LGBMRegressor                            0.706286              0.051933
# DecisionTreeRegressor                    0.673822              0.137085
# RandomForestRegressor                    0.556985              0.410391
# GradientBoostingRegressor                0.575180              0.371239
# AdaBoostRegressor                        0.548297              0.428641
# XGBRegressor                             0.639998              0.221543
# ExtraTreesRegressor                      0.592505              0.332793
# LinearRegression                         1.160362             -1.558965
# KNeighborsRegressor                      0.693272              0.086550
# SVR                                      0.677178              0.128468
# MLPRegressor                             0.866273             -0.426221
#
#                            Train PCC (5 fold CV)  Train SCC (5 fold CV)  \
# LGBMRegressor                           0.316680               0.298365
# DecisionTreeRegressor                   0.586595               0.578950
# RandomForestRegressor                   0.650621               0.686715
# GradientBoostingRegressor               0.646906               0.652547
# AdaBoostRegressor                       0.672120               0.701417
# XGBRegressor                            0.587984               0.649280
# ExtraTreesRegressor                     0.582350               0.635078
# LinearRegression                        0.131250               0.141625
# KNeighborsRegressor                     0.369006               0.438564
# SVR                                     0.386355               0.371235
# MLPRegressor                            0.430860               0.454959
#
#                            Test MSE  Test MAE  Test RMSE   Test R2  Test PCC  \
# LGBMRegressor              0.520286  0.591037   0.721309  0.272460  0.554981
# DecisionTreeRegressor      0.433318  0.485460   0.658269  0.394071  0.634516
# RandomForestRegressor      0.335104  0.418653   0.578882  0.531408  0.752178
# GradientBoostingRegressor  0.342794  0.425769   0.585486  0.520656  0.742117
# AdaBoostRegressor          0.341409  0.412172   0.584302  0.522593  0.743594
# XGBRegressor               0.273350  0.409087   0.522829  0.617762  0.860025
# ExtraTreesRegressor        0.290871  0.391398   0.539324  0.593262  0.846068
# LinearRegression           0.803027  0.717383   0.896118 -0.122910  0.227078
# KNeighborsRegressor        0.400716  0.481264   0.633021  0.439660  0.681463
# SVR                        0.376078  0.461490   0.613252  0.474112  0.729364
# MLPRegressor               1.090373  0.917331   1.044209 -0.524720  0.437491
#
#                            Test SCC
# LGBMRegressor              0.490360
# DecisionTreeRegressor      0.506889
# RandomForestRegressor      0.647385
# GradientBoostingRegressor  0.666669
# AdaBoostRegressor          0.661160
# XGBRegressor               0.685953
# ExtraTreesRegressor        0.738295
# LinearRegression           0.165290
# KNeighborsRegressor        0.666669
# SVR                        0.672179
# MLPRegressor               0.366393  )])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import os
import pandas as pd

plots_dir = '/home/users/akshay/PCPpred/MDCK/results/Ablation/plots'
os.makedirs(plots_dir, exist_ok=True)

actual_values = {
    "Test MSE": 0.247394,
    "Test MAE": 0.390254,
    "Test RMSE": 0.497387,
    "Test R2": 0.654058,
    "Test PCC": 0.894086,
    "Test SCC": 0.878791
}

metrics = ["Test MSE", "Test MAE", "Test RMSE", "Test R2", "Test PCC", "Test SCC"]
y_label = {"Test MSE":"MSE score", "Test MAE":"MAE score", "Test RMSE":"RMSE score", "Test R2":"R2 score", "Test PCC":"PCC score", "Test SCC":"SCC score"}
num_bars = len(ablation_results)
colors = cm.get_cmap('tab10', num_bars).colors

for metric in metrics:
    metric_data = {label: df.loc["XGBRegressor", metric] for label, df in ablation_results.items()}
    metric_series = pd.Series(metric_data)

    fig, ax = plt.subplots(figsize=(5, 7))
    bars = ax.bar(metric_series.index, metric_series.values, color=colors, edgecolor='black', linewidth=1.2)

    y_max = metric_series.max()
    if metric == 'Test R2':
        ax.set_ylim(0.0, y_max + 0.2)
    if metric == 'Test MSE':
        ax.set_ylim(0.0, y_max + 0.05)
    if metric == 'Test RMSE':
        ax.set_ylim(0.0, y_max + 0.07)
    if metric == 'Test PCC':
        ax.set_ylim(0.0, y_max + 0.2)
    if metric == 'Test SCC':
        ax.set_ylim(0.0, y_max + 0.2)
    if metric == 'Test MAE':
        ax.set_ylim(0.0, y_max + 0.05)

    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

    actual_value = actual_values[metric]
    ax.axhline(y=actual_value, color='red', linestyle='--', linewidth=1.5,
               label=f'Actual {metric.split()[-1]}: {actual_value:.4f}')

    ax.legend(loc='upper right', fontsize=9)

    ax.set_title(f'MDCK {metric}', fontsize=14)
    ax.set_xlabel('Ablation Study', fontsize=10)
    
    ax.set_ylabel(y_label[metric], fontsize=10)
    ax.set_xticks(range(len(metric_series)))
    ax.set_xticklabels(metric_series.index, rotation=55, ha='right')
    ax.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()

    save_path = os.path.join(plots_dir, f"{metric.replace(' ', '_')}.png")
    plt.savefig(save_path, dpi=300)
    print(f"Saved plot for {metric} to {save_path}")
    plt.show()
# Out:
# /tmp/ipykernel_1791314/1541827267.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap('tab10', num_bars).colors
# Saved plot for Test MSE to /home/users/akshay/PCPpred/MDCK/results/Ablation/plots/Test_MSE.png
# Saved plot for Test MAE to /home/users/akshay/PCPpred/MDCK/results/Ablation/plots/Test_MAE.png
# Saved plot for Test RMSE to /home/users/akshay/PCPpred/MDCK/results/Ablation/plots/Test_RMSE.png
# Saved plot for Test R2 to /home/users/akshay/PCPpred/MDCK/results/Ablation/plots/Test_R2.png
# Saved plot for Test PCC to /home/users/akshay/PCPpred/MDCK/results/Ablation/plots/Test_PCC.png
# Saved plot for Test SCC to /home/users/akshay/PCPpred/MDCK/results/Ablation/plots/Test_SCC.png
